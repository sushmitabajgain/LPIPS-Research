# %% [markdown]
# # 01. LPIPS vs MSE Baseline on CIFAR10
#
# Questions answered here:
#
# - Does LPIPS-trained reconstruction look different from MSE-trained reconstruction?
# - What happens on `all`, `horse`, or `frog` subsets?
# - Which model wins on LPIPS score, MSE score, and PSNR?

# %%
# If needed, uncomment the next line the first time you run the notebook.
# !pip install torch torchvision lpips matplotlib pandas pillow seaborn

import os
import math
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from torch.utils.data import DataLoader, Dataset, Subset

import lpips

sns.set_theme(style="whitegrid")
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / "data"
FIG_DIR = BASE_DIR / "generated_figures"
FIG_DIR.mkdir(exist_ok=True)
print("Using device:", DEVICE)
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.25.0+cu128)
# Requirement already satisfied: lpips in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.3)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Using device: cuda

# %%
# Reproducibility helps make LPIPS-vs-MSE comparisons fair.
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)

CIFAR10_CLASSES = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]
STL10_CLASSES = CIFAR10_CLASSES

class ConvAutoencoder(nn.Module):
    """Small convolutional autoencoder used across the notebooks."""
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, 3, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 128, 3, stride=2, padding=1),
            nn.ReLU(inplace=True),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 3, 3, padding=1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.decoder(self.encoder(x))


def to_lpips_range(x: torch.Tensor) -> torch.Tensor:
    # LPIPS expects images in [-1, 1].
    return x * 2.0 - 1.0


def psnr(pred: torch.Tensor, target: torch.Tensor) -> torch.Tensor:
    mse = torch.mean((pred - target) ** 2, dim=(1, 2, 3))
    return 10.0 * torch.log10(1.0 / (mse + 1e-8))


def build_transform(image_size: int):
    return T.Compose([
        T.Resize((image_size, image_size)),
        T.ToTensor(),
    ])


def degrade_image(image: torch.Tensor, mode: str) -> torch.Tensor:
    image = image.clone()
    if mode == "identity":
        return image
    if mode == "gaussian_noise":
        noise = 0.08 * torch.randn_like(image)
        return torch.clamp(image + noise, 0.0, 1.0)
    if mode == "blur":
        return TF.gaussian_blur(image, kernel_size=[5, 5], sigma=[1.2, 1.2])
    if mode == "downsample":
        h, w = image.shape[-2:]
        small = TF.resize(image, [max(8, h // 4), max(8, w // 4)], antialias=True)
        return TF.resize(small, [h, w], antialias=True)
    if mode == "shift":
        # Small spatial shift is useful because LPIPS and MSE can react differently.
        return torch.roll(image, shifts=(2, 2), dims=(1, 2))
    raise ValueError(f"Unknown degradation mode: {mode}")


class ReconstructionWrapper(Dataset):
    def __init__(self, base_dataset, degradation="identity"):
        self.base_dataset = base_dataset
        self.degradation = degradation

    def __len__(self):
        return len(self.base_dataset)

    def __getitem__(self, idx):
        sample = self.base_dataset[idx]
        image = sample[0] if isinstance(sample, tuple) else sample
        degraded = degrade_image(image, self.degradation)
        return degraded, image


class RepeatedSingleImageDataset(Dataset):
    def __init__(self, image: torch.Tensor, repeats: int = 256, degradation: str = "identity"):
        self.image = image
        self.repeats = repeats
        self.degradation = degradation

    def __len__(self):
        return self.repeats

    def __getitem__(self, idx):
        degraded = degrade_image(self.image, self.degradation)
        return degraded, self.image


def get_dataset(dataset_name: str, image_size: int):
    transform = build_transform(image_size)
    name = dataset_name.upper()
    if name == "CIFAR10":
        return torchvision.datasets.CIFAR10(root=str(DATA_DIR), train=True, download=True, transform=transform)
    if name == "CIFAR100":
        return torchvision.datasets.CIFAR100(root=str(DATA_DIR), train=True, download=True, transform=transform)
    if name == "STL10":
        return torchvision.datasets.STL10(root=str(DATA_DIR), split="train", download=True, transform=transform)
    if name == "CELEBA":
        return torchvision.datasets.CelebA(root=str(DATA_DIR), split="train", download=True, transform=transform)
    raise ValueError(f"Unsupported dataset: {dataset_name}")


def get_targets(dataset):
    if hasattr(dataset, "targets"):
        return [int(x) for x in dataset.targets]
    if hasattr(dataset, "labels"):
        return [int(x) for x in dataset.labels]
    return None


def filter_by_class(dataset, dataset_name: str, class_name: str, max_items: int = 1000):
    if class_name == "all":
        return dataset
    targets = get_targets(dataset)
    if targets is None:
        raise ValueError(f"Dataset {dataset_name} does not expose simple class labels for filtering.")
    if dataset_name.upper() == "CIFAR10":
        class_index = CIFAR10_CLASSES.index(class_name)
    elif dataset_name.upper() == "STL10":
        class_index = STL10_CLASSES.index(class_name)
    else:
        raise ValueError(f"Class filtering not set up for {dataset_name}.")
    indices = [i for i, target in enumerate(targets) if target == class_index][:max_items]
    return Subset(dataset, indices)


def train_two_models(train_loader, epochs=5, lpips_net="vgg"):
    base_model = ConvAutoencoder().to(DEVICE)
    model_lpips = ConvAutoencoder().to(DEVICE)
    model_mse = ConvAutoencoder().to(DEVICE)
    model_lpips.load_state_dict(base_model.state_dict())
    model_mse.load_state_dict(base_model.state_dict())

    optimizer_lpips = optim.Adam(model_lpips.parameters(), lr=1e-4)
    optimizer_mse = optim.Adam(model_mse.parameters(), lr=1e-4)
    lpips_loss = lpips.LPIPS(net=lpips_net).to(DEVICE).eval()
    mse_loss = nn.MSELoss()

    history = {"epoch": [], "lpips_train_loss": [], "mse_train_loss": []}

    for epoch in range(1, epochs + 1):
        model_lpips.train()
        model_mse.train()
        running_lpips = 0.0
        running_mse = 0.0
        batches = 0

        for degraded, clean in train_loader:
            degraded = degraded.to(DEVICE)
            clean = clean.to(DEVICE)

            optimizer_lpips.zero_grad()
            pred_lpips = model_lpips(degraded)
            loss_lp = lpips_loss(to_lpips_range(pred_lpips), to_lpips_range(clean)).mean()
            loss_lp.backward()
            optimizer_lpips.step()

            optimizer_mse.zero_grad()
            pred_mse = model_mse(degraded)
            loss_mse = mse_loss(pred_mse, clean)
            loss_mse.backward()
            optimizer_mse.step()

            running_lpips += loss_lp.item()
            running_mse += loss_mse.item()
            batches += 1

        history["epoch"].append(epoch)
        history["lpips_train_loss"].append(running_lpips / batches)
        history["mse_train_loss"].append(running_mse / batches)
        print(f"Epoch {epoch:02d} | LPIPS loss: {history['lpips_train_loss'][-1]:.4f} | MSE loss: {history['mse_train_loss'][-1]:.4f}")

    return model_lpips, model_mse, pd.DataFrame(history), lpips_loss, mse_loss


def evaluate_models(model_lpips, model_mse, loader, lpips_loss, mse_loss):
    model_lpips.eval()
    model_mse.eval()
    rows = []

    with torch.no_grad():
        for degraded, clean in loader:
            degraded = degraded.to(DEVICE)
            clean = clean.to(DEVICE)
            pred_lpips = model_lpips(degraded)
            pred_mse = model_mse(degraded)

            rows.append({
                "lpips_model_lpips": lpips_loss(to_lpips_range(pred_lpips), to_lpips_range(clean)).mean().item(),
                "mse_model_lpips": lpips_loss(to_lpips_range(pred_mse), to_lpips_range(clean)).mean().item(),
                "lpips_model_mse": mse_loss(pred_lpips, clean).item(),
                "mse_model_mse": mse_loss(pred_mse, clean).item(),
                "lpips_model_psnr": psnr(pred_lpips, clean).mean().item(),
                "mse_model_psnr": psnr(pred_mse, clean).mean().item(),
            })
    return pd.DataFrame(rows).mean().to_frame(name="value")


def show_reconstructions(model_lpips, model_mse, loader, title, n=5):
    degraded, clean = next(iter(loader))
    degraded = degraded.to(DEVICE)
    clean = clean.to(DEVICE)
    with torch.no_grad():
        pred_lpips = model_lpips(degraded).cpu()
        pred_mse = model_mse(degraded).cpu()
    degraded = degraded.cpu()
    clean = clean.cpu()

    n = min(n, degraded.size(0))
    plt.figure(figsize=(3 * n, 8))
    for i in range(n):
        plt.subplot(4, n, i + 1)
        plt.imshow(degraded[i].permute(1, 2, 0))
        plt.title("Input")
        plt.axis("off")

        plt.subplot(4, n, n + i + 1)
        plt.imshow(clean[i].permute(1, 2, 0))
        plt.title("Target")
        plt.axis("off")

        plt.subplot(4, n, 2 * n + i + 1)
        plt.imshow(pred_lpips[i].permute(1, 2, 0))
        plt.title("LPIPS")
        plt.axis("off")

        plt.subplot(4, n, 3 * n + i + 1)
        plt.imshow(pred_mse[i].permute(1, 2, 0))
        plt.title("MSE")
        plt.axis("off")

    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

# %%
# Edit these settings as needed.
DATASET_NAME = "CIFAR10"
CLASS_NAME = "horse"   # Try: "all", "horse", "frog"
IMAGE_SIZE = 64
DEGRADATION = "identity"  # Try: "identity", "gaussian_noise", "blur", "downsample"
TRAIN_SAMPLES = 512
VAL_SAMPLES = 128
BATCH_SIZE = 32
EPOCHS = 500
LPIPS_NET = "vgg"

# %%
# Prepare the dataset and optional class filter.
base_dataset = get_dataset(DATASET_NAME, IMAGE_SIZE)
base_dataset = filter_by_class(base_dataset, DATASET_NAME, CLASS_NAME, max_items=TRAIN_SAMPLES + VAL_SAMPLES)

if isinstance(base_dataset, Subset):
    indices = base_dataset.indices
else:
    indices = list(range(len(base_dataset)))

train_indices = indices[:TRAIN_SAMPLES]
val_indices = indices[TRAIN_SAMPLES:TRAIN_SAMPLES + VAL_SAMPLES]
if len(val_indices) == 0:
    val_indices = indices[:min(VAL_SAMPLES, len(indices))]

train_dataset = ReconstructionWrapper(Subset(base_dataset.dataset if isinstance(base_dataset, Subset) else base_dataset, train_indices) if isinstance(base_dataset, Subset) else Subset(base_dataset, train_indices), degradation=DEGRADATION)
val_dataset = ReconstructionWrapper(Subset(base_dataset.dataset if isinstance(base_dataset, Subset) else base_dataset, val_indices) if isinstance(base_dataset, Subset) else Subset(base_dataset, val_indices), degradation=DEGRADATION)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
print(f"Train samples: {len(train_dataset)} | Val samples: {len(val_dataset)}")
# Out:
# Train samples: 512 | Val samples: 128

# %%
# Train both models from the same initialization for a fair comparison.
model_lpips, model_mse, history_df, lpips_loss, mse_loss = train_two_models(
    train_loader,
    epochs=EPOCHS,
    lpips_net=LPIPS_NET,
)

history_df
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Epoch 01 | LPIPS loss: 0.8157 | MSE loss: 0.0605
# Epoch 02 | LPIPS loss: 0.8128 | MSE loss: 0.0599
# Epoch 03 | LPIPS loss: 0.7993 | MSE loss: 0.0579
# Epoch 04 | LPIPS loss: 0.7506 | MSE loss: 0.0494
# Epoch 05 | LPIPS loss: 0.7332 | MSE loss: 0.0270
# Epoch 06 | LPIPS loss: 0.7068 | MSE loss: 0.0146
# Epoch 07 | LPIPS loss: 0.6746 | MSE loss: 0.0118
# Epoch 08 | LPIPS loss: 0.6424 | MSE loss: 0.0107
# Epoch 09 | LPIPS loss: 0.6083 | MSE loss: 0.0100
# Epoch 10 | LPIPS loss: 0.5732 | MSE loss: 0.0095
# Epoch 11 | LPIPS loss: 0.5363 | MSE loss: 0.0090
# Epoch 12 | LPIPS loss: 0.4985 | MSE loss: 0.0086
# Epoch 13 | LPIPS loss: 0.4640 | MSE loss: 0.0082
# Epoch 14 | LPIPS loss: 0.4308 | MSE loss: 0.0078
# Epoch 15 | LPIPS loss: 0.3983 | MSE loss: 0.0074
# Epoch 16 | LPIPS loss: 0.3717 | MSE loss: 0.0071
# Epoch 17 | LPIPS loss: 0.3495 | MSE loss: 0.0067
# Epoch 18 | LPIPS loss: 0.3305 | MSE loss: 0.0065
# Epoch 19 | LPIPS loss: 0.3127 | MSE loss: 0.0062
# Epoch 20 | LPIPS loss: 0.2989 | MSE loss: 0.0060
# Epoch 21 | LPIPS loss: 0.2886 | MSE loss: 0.0058
# Epoch 22 | LPIPS loss: 0.2803 | MSE loss: 0.0057
# Epoch 23 | LPIPS loss: 0.2700 | MSE loss: 0.0056
# Epoch 24 | LPIPS loss: 0.2629 | MSE loss: 0.0055
# Epoch 25 | LPIPS loss: 0.2567 | MSE loss: 0.0054
# Epoch 26 | LPIPS loss: 0.2510 | MSE loss: 0.0052
# Epoch 27 | LPIPS loss: 0.2451 | MSE loss: 0.0051
# Epoch 28 | LPIPS loss: 0.2401 | MSE loss: 0.0050
# Epoch 29 | LPIPS loss: 0.2360 | MSE loss: 0.0049
# Epoch 30 | LPIPS loss: 0.2298 | MSE loss: 0.0048
# Epoch 31 | LPIPS loss: 0.2212 | MSE loss: 0.0047
# Epoch 32 | LPIPS loss: 0.2134 | MSE loss: 0.0045
# Epoch 33 | LPIPS loss: 0.2055 | MSE loss: 0.0044
# Epoch 34 | LPIPS loss: 0.1952 | MSE loss: 0.0042
# Epoch 35 | LPIPS loss: 0.1847 | MSE loss: 0.0040
# Epoch 36 | LPIPS loss: 0.1754 | MSE loss: 0.0037
# Epoch 37 | LPIPS loss: 0.1698 | MSE loss: 0.0035
# Epoch 38 | LPIPS loss: 0.1617 | MSE loss: 0.0033
# Epoch 39 | LPIPS loss: 0.1574 | MSE loss: 0.0031
# Epoch 40 | LPIPS loss: 0.1548 | MSE loss: 0.0030
# Epoch 41 | LPIPS loss: 0.1600 | MSE loss: 0.0029
# Epoch 42 | LPIPS loss: 0.1476 | MSE loss: 0.0028
# Epoch 43 | LPIPS loss: 0.1432 | MSE loss: 0.0027
# Epoch 44 | LPIPS loss: 0.1397 | MSE loss: 0.0026
# Epoch 45 | LPIPS loss: 0.1359 | MSE loss: 0.0025
# Epoch 46 | LPIPS loss: 0.1329 | MSE loss: 0.0025
# Epoch 47 | LPIPS loss: 0.1308 | MSE loss: 0.0025
# Epoch 48 | LPIPS loss: 0.1275 | MSE loss: 0.0025
# Epoch 49 | LPIPS loss: 0.1263 | MSE loss: 0.0024
# Epoch 50 | LPIPS loss: 0.1253 | MSE loss: 0.0024
# Epoch 51 | LPIPS loss: 0.1217 | MSE loss: 0.0024
# Epoch 52 | LPIPS loss: 0.1187 | MSE loss: 0.0023
# Epoch 53 | LPIPS loss: 0.1155 | MSE loss: 0.0023
# Epoch 54 | LPIPS loss: 0.1129 | MSE loss: 0.0023
# Epoch 55 | LPIPS loss: 0.1105 | MSE loss: 0.0022
# Epoch 56 | LPIPS loss: 0.1092 | MSE loss: 0.0022
# Epoch 57 | LPIPS loss: 0.1115 | MSE loss: 0.0022
# Epoch 58 | LPIPS loss: 0.1164 | MSE loss: 0.0021
# Epoch 59 | LPIPS loss: 0.1116 | MSE loss: 0.0021
# Epoch 60 | LPIPS loss: 0.1044 | MSE loss: 0.0021
# Epoch 61 | LPIPS loss: 0.1006 | MSE loss: 0.0021
# Epoch 62 | LPIPS loss: 0.0999 | MSE loss: 0.0021
# Epoch 63 | LPIPS loss: 0.1055 | MSE loss: 0.0021
# Epoch 64 | LPIPS loss: 0.1082 | MSE loss: 0.0021
# Epoch 65 | LPIPS loss: 0.0982 | MSE loss: 0.0020
# Epoch 66 | LPIPS loss: 0.0938 | MSE loss: 0.0020
# Epoch 67 | LPIPS loss: 0.0914 | MSE loss: 0.0020
# Epoch 68 | LPIPS loss: 0.0896 | MSE loss: 0.0020
# Epoch 69 | LPIPS loss: 0.0880 | MSE loss: 0.0019
# Epoch 70 | LPIPS loss: 0.0867 | MSE loss: 0.0020
# Epoch 71 | LPIPS loss: 0.0858 | MSE loss: 0.0019
# Epoch 72 | LPIPS loss: 0.0839 | MSE loss: 0.0019
# Epoch 73 | LPIPS loss: 0.0828 | MSE loss: 0.0019
# Epoch 74 | LPIPS loss: 0.0816 | MSE loss: 0.0019
# Epoch 75 | LPIPS loss: 0.0800 | MSE loss: 0.0018
# Epoch 76 | LPIPS loss: 0.0788 | MSE loss: 0.0018
# Epoch 77 | LPIPS loss: 0.0781 | MSE loss: 0.0018
# Epoch 78 | LPIPS loss: 0.0764 | MSE loss: 0.0018
# Epoch 79 | LPIPS loss: 0.0751 | MSE loss: 0.0018
# Epoch 80 | LPIPS loss: 0.0741 | MSE loss: 0.0018
# Epoch 81 | LPIPS loss: 0.0732 | MSE loss: 0.0018
# Epoch 82 | LPIPS loss: 0.0724 | MSE loss: 0.0018
# Epoch 83 | LPIPS loss: 0.0711 | MSE loss: 0.0018
# Epoch 84 | LPIPS loss: 0.0757 | MSE loss: 0.0017
# Epoch 85 | LPIPS loss: 0.0728 | MSE loss: 0.0017
# Epoch 86 | LPIPS loss: 0.0731 | MSE loss: 0.0017
# Epoch 87 | LPIPS loss: 0.0804 | MSE loss: 0.0017
# Epoch 88 | LPIPS loss: 0.0749 | MSE loss: 0.0017
# Epoch 89 | LPIPS loss: 0.0705 | MSE loss: 0.0017
# Epoch 90 | LPIPS loss: 0.0663 | MSE loss: 0.0016
# Epoch 91 | LPIPS loss: 0.0649 | MSE loss: 0.0016
# Epoch 92 | LPIPS loss: 0.0639 | MSE loss: 0.0017
# Epoch 93 | LPIPS loss: 0.0631 | MSE loss: 0.0017
# Epoch 94 | LPIPS loss: 0.0621 | MSE loss: 0.0016
# Epoch 95 | LPIPS loss: 0.0612 | MSE loss: 0.0016
# Epoch 96 | LPIPS loss: 0.0605 | MSE loss: 0.0016
# Epoch 97 | LPIPS loss: 0.0596 | MSE loss: 0.0016
# Epoch 98 | LPIPS loss: 0.0593 | MSE loss: 0.0016
# Epoch 99 | LPIPS loss: 0.0584 | MSE loss: 0.0015
# Epoch 100 | LPIPS loss: 0.0579 | MSE loss: 0.0015
# Epoch 101 | LPIPS loss: 0.0574 | MSE loss: 0.0015
# Epoch 102 | LPIPS loss: 0.0570 | MSE loss: 0.0015
# Epoch 103 | LPIPS loss: 0.0574 | MSE loss: 0.0015
# Epoch 104 | LPIPS loss: 0.0593 | MSE loss: 0.0015
# Epoch 105 | LPIPS loss: 0.0564 | MSE loss: 0.0015
# Epoch 106 | LPIPS loss: 0.0547 | MSE loss: 0.0015
# Epoch 107 | LPIPS loss: 0.0565 | MSE loss: 0.0015
# Epoch 108 | LPIPS loss: 0.0550 | MSE loss: 0.0015
# Epoch 109 | LPIPS loss: 0.0531 | MSE loss: 0.0015
# Epoch 110 | LPIPS loss: 0.0523 | MSE loss: 0.0014
# Epoch 111 | LPIPS loss: 0.0519 | MSE loss: 0.0014
# Epoch 112 | LPIPS loss: 0.0520 | MSE loss: 0.0014
# Epoch 113 | LPIPS loss: 0.0528 | MSE loss: 0.0014
# Epoch 114 | LPIPS loss: 0.0523 | MSE loss: 0.0014
# Epoch 115 | LPIPS loss: 0.0516 | MSE loss: 0.0014
# Epoch 116 | LPIPS loss: 0.0501 | MSE loss: 0.0014
# Epoch 117 | LPIPS loss: 0.0491 | MSE loss: 0.0013
# Epoch 118 | LPIPS loss: 0.0486 | MSE loss: 0.0014
# Epoch 119 | LPIPS loss: 0.0483 | MSE loss: 0.0013
# Epoch 120 | LPIPS loss: 0.0476 | MSE loss: 0.0013
# Epoch 121 | LPIPS loss: 0.0475 | MSE loss: 0.0013
# Epoch 122 | LPIPS loss: 0.0469 | MSE loss: 0.0012
# Epoch 123 | LPIPS loss: 0.0467 | MSE loss: 0.0012
# Epoch 124 | LPIPS loss: 0.0475 | MSE loss: 0.0012
# Epoch 125 | LPIPS loss: 0.0465 | MSE loss: 0.0012
# Epoch 126 | LPIPS loss: 0.0473 | MSE loss: 0.0012
# Epoch 127 | LPIPS loss: 0.0534 | MSE loss: 0.0011
# Epoch 128 | LPIPS loss: 0.0540 | MSE loss: 0.0011
# Epoch 129 | LPIPS loss: 0.0514 | MSE loss: 0.0011
# Epoch 130 | LPIPS loss: 0.0524 | MSE loss: 0.0010
# Epoch 131 | LPIPS loss: 0.0552 | MSE loss: 0.0010
# Epoch 132 | LPIPS loss: 0.0482 | MSE loss: 0.0010
# Epoch 133 | LPIPS loss: 0.0449 | MSE loss: 0.0009
# Epoch 134 | LPIPS loss: 0.0437 | MSE loss: 0.0009
# Epoch 135 | LPIPS loss: 0.0431 | MSE loss: 0.0009
# Epoch 136 | LPIPS loss: 0.0426 | MSE loss: 0.0009
# Epoch 137 | LPIPS loss: 0.0425 | MSE loss: 0.0008
# Epoch 138 | LPIPS loss: 0.0420 | MSE loss: 0.0008
# Epoch 139 | LPIPS loss: 0.0415 | MSE loss: 0.0008
# Epoch 140 | LPIPS loss: 0.0411 | MSE loss: 0.0008
# Epoch 141 | LPIPS loss: 0.0407 | MSE loss: 0.0008
# Epoch 142 | LPIPS loss: 0.0404 | MSE loss: 0.0008
# Epoch 143 | LPIPS loss: 0.0408 | MSE loss: 0.0008
# Epoch 144 | LPIPS loss: 0.0401 | MSE loss: 0.0008
# Epoch 145 | LPIPS loss: 0.0395 | MSE loss: 0.0007
# Epoch 146 | LPIPS loss: 0.0392 | MSE loss: 0.0007
# Epoch 147 | LPIPS loss: 0.0389 | MSE loss: 0.0007
# Epoch 148 | LPIPS loss: 0.0387 | MSE loss: 0.0007
# Epoch 149 | LPIPS loss: 0.0386 | MSE loss: 0.0007
# Epoch 150 | LPIPS loss: 0.0385 | MSE loss: 0.0007
# Epoch 151 | LPIPS loss: 0.0383 | MSE loss: 0.0007
# Epoch 152 | LPIPS loss: 0.0383 | MSE loss: 0.0007
# Epoch 153 | LPIPS loss: 0.0377 | MSE loss: 0.0007
# Epoch 154 | LPIPS loss: 0.0372 | MSE loss: 0.0006
# Epoch 155 | LPIPS loss: 0.0369 | MSE loss: 0.0006
# Epoch 156 | LPIPS loss: 0.0369 | MSE loss: 0.0007
# Epoch 157 | LPIPS loss: 0.0368 | MSE loss: 0.0007
# Epoch 158 | LPIPS loss: 0.0363 | MSE loss: 0.0006
# Epoch 159 | LPIPS loss: 0.0366 | MSE loss: 0.0006
# Epoch 160 | LPIPS loss: 0.0435 | MSE loss: 0.0006
# Epoch 161 | LPIPS loss: 0.0450 | MSE loss: 0.0006
# Epoch 162 | LPIPS loss: 0.0434 | MSE loss: 0.0006
# Epoch 163 | LPIPS loss: 0.0485 | MSE loss: 0.0006
# Epoch 164 | LPIPS loss: 0.0441 | MSE loss: 0.0006
# Epoch 165 | LPIPS loss: 0.0374 | MSE loss: 0.0006
# Epoch 166 | LPIPS loss: 0.0358 | MSE loss: 0.0006
# Epoch 167 | LPIPS loss: 0.0350 | MSE loss: 0.0006
# Epoch 168 | LPIPS loss: 0.0346 | MSE loss: 0.0006
# Epoch 169 | LPIPS loss: 0.0343 | MSE loss: 0.0006
# Epoch 170 | LPIPS loss: 0.0340 | MSE loss: 0.0006
# Epoch 171 | LPIPS loss: 0.0338 | MSE loss: 0.0006
# Epoch 172 | LPIPS loss: 0.0335 | MSE loss: 0.0006
# Epoch 173 | LPIPS loss: 0.0334 | MSE loss: 0.0006
# Epoch 174 | LPIPS loss: 0.0331 | MSE loss: 0.0006
# Epoch 175 | LPIPS loss: 0.0330 | MSE loss: 0.0006
# Epoch 176 | LPIPS loss: 0.0327 | MSE loss: 0.0006
# Epoch 177 | LPIPS loss: 0.0325 | MSE loss: 0.0005
# Epoch 178 | LPIPS loss: 0.0325 | MSE loss: 0.0005
# Epoch 179 | LPIPS loss: 0.0321 | MSE loss: 0.0005
# Epoch 180 | LPIPS loss: 0.0320 | MSE loss: 0.0005
# Epoch 181 | LPIPS loss: 0.0322 | MSE loss: 0.0005
# Epoch 182 | LPIPS loss: 0.0316 | MSE loss: 0.0005
# Epoch 183 | LPIPS loss: 0.0314 | MSE loss: 0.0005
# Epoch 184 | LPIPS loss: 0.0313 | MSE loss: 0.0005
# Epoch 185 | LPIPS loss: 0.0311 | MSE loss: 0.0005
# Epoch 186 | LPIPS loss: 0.0311 | MSE loss: 0.0005
# Epoch 187 | LPIPS loss: 0.0313 | MSE loss: 0.0005
# Epoch 188 | LPIPS loss: 0.0308 | MSE loss: 0.0005
# Epoch 189 | LPIPS loss: 0.0306 | MSE loss: 0.0005
# Epoch 190 | LPIPS loss: 0.0305 | MSE loss: 0.0005
# Epoch 191 | LPIPS loss: 0.0304 | MSE loss: 0.0005
# Epoch 192 | LPIPS loss: 0.0303 | MSE loss: 0.0005
# Epoch 193 | LPIPS loss: 0.0302 | MSE loss: 0.0005
# Epoch 194 | LPIPS loss: 0.0297 | MSE loss: 0.0005
# Epoch 195 | LPIPS loss: 0.0296 | MSE loss: 0.0005
# Epoch 196 | LPIPS loss: 0.0295 | MSE loss: 0.0005
# Epoch 197 | LPIPS loss: 0.0294 | MSE loss: 0.0005
# Epoch 198 | LPIPS loss: 0.0296 | MSE loss: 0.0005
# Epoch 199 | LPIPS loss: 0.0292 | MSE loss: 0.0005
# Epoch 200 | LPIPS loss: 0.0289 | MSE loss: 0.0005
# Epoch 201 | LPIPS loss: 0.0290 | MSE loss: 0.0005
# Epoch 202 | LPIPS loss: 0.0291 | MSE loss: 0.0005
# Epoch 203 | LPIPS loss: 0.0287 | MSE loss: 0.0005
# Epoch 204 | LPIPS loss: 0.0284 | MSE loss: 0.0005
# Epoch 205 | LPIPS loss: 0.0283 | MSE loss: 0.0005
# Epoch 206 | LPIPS loss: 0.0282 | MSE loss: 0.0004
# Epoch 207 | LPIPS loss: 0.0280 | MSE loss: 0.0005
# Epoch 208 | LPIPS loss: 0.0280 | MSE loss: 0.0005
# Epoch 209 | LPIPS loss: 0.0281 | MSE loss: 0.0005
# Epoch 210 | LPIPS loss: 0.0276 | MSE loss: 0.0004
# Epoch 211 | LPIPS loss: 0.0276 | MSE loss: 0.0005
# Epoch 212 | LPIPS loss: 0.0276 | MSE loss: 0.0006
# Epoch 213 | LPIPS loss: 0.0276 | MSE loss: 0.0005
# Epoch 214 | LPIPS loss: 0.0273 | MSE loss: 0.0005
# Epoch 215 | LPIPS loss: 0.0271 | MSE loss: 0.0004
# Epoch 216 | LPIPS loss: 0.0273 | MSE loss: 0.0004
# Epoch 217 | LPIPS loss: 0.0285 | MSE loss: 0.0004
# Epoch 218 | LPIPS loss: 0.0309 | MSE loss: 0.0004
# Epoch 219 | LPIPS loss: 0.0487 | MSE loss: 0.0004
# Epoch 220 | LPIPS loss: 0.0366 | MSE loss: 0.0004
# Epoch 221 | LPIPS loss: 0.0385 | MSE loss: 0.0004
# Epoch 222 | LPIPS loss: 0.0286 | MSE loss: 0.0004
# Epoch 223 | LPIPS loss: 0.0274 | MSE loss: 0.0004
# Epoch 224 | LPIPS loss: 0.0267 | MSE loss: 0.0004
# Epoch 225 | LPIPS loss: 0.0264 | MSE loss: 0.0004
# Epoch 226 | LPIPS loss: 0.0261 | MSE loss: 0.0004
# Epoch 227 | LPIPS loss: 0.0259 | MSE loss: 0.0004
# Epoch 228 | LPIPS loss: 0.0258 | MSE loss: 0.0004
# Epoch 229 | LPIPS loss: 0.0258 | MSE loss: 0.0004
# Epoch 230 | LPIPS loss: 0.0258 | MSE loss: 0.0004
# Epoch 231 | LPIPS loss: 0.0255 | MSE loss: 0.0004
# Epoch 232 | LPIPS loss: 0.0254 | MSE loss: 0.0004
# Epoch 233 | LPIPS loss: 0.0252 | MSE loss: 0.0004
# Epoch 234 | LPIPS loss: 0.0250 | MSE loss: 0.0004
# Epoch 235 | LPIPS loss: 0.0249 | MSE loss: 0.0004
# Epoch 236 | LPIPS loss: 0.0249 | MSE loss: 0.0004
# Epoch 237 | LPIPS loss: 0.0247 | MSE loss: 0.0004
# Epoch 238 | LPIPS loss: 0.0246 | MSE loss: 0.0005
# Epoch 239 | LPIPS loss: 0.0246 | MSE loss: 0.0004
# Epoch 240 | LPIPS loss: 0.0248 | MSE loss: 0.0004
# Epoch 241 | LPIPS loss: 0.0248 | MSE loss: 0.0004
# Epoch 242 | LPIPS loss: 0.0244 | MSE loss: 0.0004
# Epoch 243 | LPIPS loss: 0.0245 | MSE loss: 0.0004
# Epoch 244 | LPIPS loss: 0.0243 | MSE loss: 0.0004
# Epoch 245 | LPIPS loss: 0.0240 | MSE loss: 0.0004
# Epoch 246 | LPIPS loss: 0.0239 | MSE loss: 0.0004
# Epoch 247 | LPIPS loss: 0.0239 | MSE loss: 0.0004
# Epoch 248 | LPIPS loss: 0.0238 | MSE loss: 0.0004
# Epoch 249 | LPIPS loss: 0.0237 | MSE loss: 0.0004
# Epoch 250 | LPIPS loss: 0.0238 | MSE loss: 0.0004
# Epoch 251 | LPIPS loss: 0.0237 | MSE loss: 0.0004
# Epoch 252 | LPIPS loss: 0.0266 | MSE loss: 0.0004
# Epoch 253 | LPIPS loss: 0.0250 | MSE loss: 0.0004
# Epoch 254 | LPIPS loss: 0.0247 | MSE loss: 0.0004
# Epoch 255 | LPIPS loss: 0.0238 | MSE loss: 0.0004
# Epoch 256 | LPIPS loss: 0.0233 | MSE loss: 0.0003
# Epoch 257 | LPIPS loss: 0.0231 | MSE loss: 0.0003
# Epoch 258 | LPIPS loss: 0.0230 | MSE loss: 0.0003
# Epoch 259 | LPIPS loss: 0.0232 | MSE loss: 0.0004
# Epoch 260 | LPIPS loss: 0.0234 | MSE loss: 0.0004
# Epoch 261 | LPIPS loss: 0.0231 | MSE loss: 0.0003
# Epoch 262 | LPIPS loss: 0.0225 | MSE loss: 0.0003
# Epoch 263 | LPIPS loss: 0.0224 | MSE loss: 0.0003
# Epoch 264 | LPIPS loss: 0.0224 | MSE loss: 0.0003
# Epoch 265 | LPIPS loss: 0.0226 | MSE loss: 0.0003
# Epoch 266 | LPIPS loss: 0.0226 | MSE loss: 0.0004
# Epoch 267 | LPIPS loss: 0.0226 | MSE loss: 0.0004
# Epoch 268 | LPIPS loss: 0.0222 | MSE loss: 0.0003
# Epoch 269 | LPIPS loss: 0.0221 | MSE loss: 0.0003
# Epoch 270 | LPIPS loss: 0.0219 | MSE loss: 0.0003
# Epoch 271 | LPIPS loss: 0.0220 | MSE loss: 0.0003
# Epoch 272 | LPIPS loss: 0.0218 | MSE loss: 0.0003
# Epoch 273 | LPIPS loss: 0.0221 | MSE loss: 0.0003
# Epoch 274 | LPIPS loss: 0.0220 | MSE loss: 0.0003
# Epoch 275 | LPIPS loss: 0.0224 | MSE loss: 0.0003
# Epoch 276 | LPIPS loss: 0.0217 | MSE loss: 0.0003
# Epoch 277 | LPIPS loss: 0.0217 | MSE loss: 0.0003
# Epoch 278 | LPIPS loss: 0.0213 | MSE loss: 0.0003
# Epoch 279 | LPIPS loss: 0.0213 | MSE loss: 0.0003
# Epoch 280 | LPIPS loss: 0.0213 | MSE loss: 0.0003
# Epoch 281 | LPIPS loss: 0.0212 | MSE loss: 0.0003
# Epoch 282 | LPIPS loss: 0.0215 | MSE loss: 0.0003
# Epoch 283 | LPIPS loss: 0.0210 | MSE loss: 0.0003
# Epoch 284 | LPIPS loss: 0.0210 | MSE loss: 0.0003
# Epoch 285 | LPIPS loss: 0.0212 | MSE loss: 0.0003
# Epoch 286 | LPIPS loss: 0.0226 | MSE loss: 0.0003
# Epoch 287 | LPIPS loss: 0.0218 | MSE loss: 0.0005
# Epoch 288 | LPIPS loss: 0.0249 | MSE loss: 0.0004
# Epoch 289 | LPIPS loss: 0.0238 | MSE loss: 0.0003
# Epoch 290 | LPIPS loss: 0.0233 | MSE loss: 0.0003
# Epoch 291 | LPIPS loss: 0.0219 | MSE loss: 0.0003
# Epoch 292 | LPIPS loss: 0.0209 | MSE loss: 0.0003
# Epoch 293 | LPIPS loss: 0.0205 | MSE loss: 0.0003
# Epoch 294 | LPIPS loss: 0.0203 | MSE loss: 0.0003
# Epoch 295 | LPIPS loss: 0.0203 | MSE loss: 0.0003
# Epoch 296 | LPIPS loss: 0.0202 | MSE loss: 0.0003
# Epoch 297 | LPIPS loss: 0.0201 | MSE loss: 0.0003
# Epoch 298 | LPIPS loss: 0.0201 | MSE loss: 0.0003
# Epoch 299 | LPIPS loss: 0.0200 | MSE loss: 0.0003
# Epoch 300 | LPIPS loss: 0.0200 | MSE loss: 0.0003
# Epoch 301 | LPIPS loss: 0.0201 | MSE loss: 0.0003
# Epoch 302 | LPIPS loss: 0.0198 | MSE loss: 0.0003
# Epoch 303 | LPIPS loss: 0.0196 | MSE loss: 0.0003
# Epoch 304 | LPIPS loss: 0.0197 | MSE loss: 0.0003
# Epoch 305 | LPIPS loss: 0.0198 | MSE loss: 0.0003
# Epoch 306 | LPIPS loss: 0.0195 | MSE loss: 0.0003
# Epoch 307 | LPIPS loss: 0.0197 | MSE loss: 0.0003
# Epoch 308 | LPIPS loss: 0.0197 | MSE loss: 0.0003
# Epoch 309 | LPIPS loss: 0.0193 | MSE loss: 0.0003
# Epoch 310 | LPIPS loss: 0.0191 | MSE loss: 0.0003
# Epoch 311 | LPIPS loss: 0.0190 | MSE loss: 0.0003
# Epoch 312 | LPIPS loss: 0.0190 | MSE loss: 0.0003
# Epoch 313 | LPIPS loss: 0.0190 | MSE loss: 0.0003
# Epoch 314 | LPIPS loss: 0.0190 | MSE loss: 0.0003
# Epoch 315 | LPIPS loss: 0.0190 | MSE loss: 0.0003
# Epoch 316 | LPIPS loss: 0.0189 | MSE loss: 0.0003
# Epoch 317 | LPIPS loss: 0.0200 | MSE loss: 0.0003
# Epoch 318 | LPIPS loss: 0.0191 | MSE loss: 0.0003
# Epoch 319 | LPIPS loss: 0.0190 | MSE loss: 0.0003
# Epoch 320 | LPIPS loss: 0.0189 | MSE loss: 0.0003
# Epoch 321 | LPIPS loss: 0.0187 | MSE loss: 0.0003
# Epoch 322 | LPIPS loss: 0.0189 | MSE loss: 0.0003
# Epoch 323 | LPIPS loss: 0.0195 | MSE loss: 0.0003
# Epoch 324 | LPIPS loss: 0.0186 | MSE loss: 0.0003
# Epoch 325 | LPIPS loss: 0.0183 | MSE loss: 0.0003
# Epoch 326 | LPIPS loss: 0.0182 | MSE loss: 0.0003
# Epoch 327 | LPIPS loss: 0.0181 | MSE loss: 0.0003
# Epoch 328 | LPIPS loss: 0.0180 | MSE loss: 0.0003
# Epoch 329 | LPIPS loss: 0.0179 | MSE loss: 0.0003
# Epoch 330 | LPIPS loss: 0.0179 | MSE loss: 0.0003
# Epoch 331 | LPIPS loss: 0.0184 | MSE loss: 0.0003
# Epoch 332 | LPIPS loss: 0.0186 | MSE loss: 0.0003
# Epoch 333 | LPIPS loss: 0.0182 | MSE loss: 0.0003
# Epoch 334 | LPIPS loss: 0.0179 | MSE loss: 0.0003
# Epoch 335 | LPIPS loss: 0.0179 | MSE loss: 0.0003
# Epoch 336 | LPIPS loss: 0.0186 | MSE loss: 0.0003
# Epoch 337 | LPIPS loss: 0.0183 | MSE loss: 0.0003
# Epoch 338 | LPIPS loss: 0.0178 | MSE loss: 0.0003
# Epoch 339 | LPIPS loss: 0.0176 | MSE loss: 0.0003
# Epoch 340 | LPIPS loss: 0.0174 | MSE loss: 0.0003
# Epoch 341 | LPIPS loss: 0.0176 | MSE loss: 0.0003
# Epoch 342 | LPIPS loss: 0.0177 | MSE loss: 0.0003
# Epoch 343 | LPIPS loss: 0.0173 | MSE loss: 0.0003
# Epoch 344 | LPIPS loss: 0.0175 | MSE loss: 0.0003
# Epoch 345 | LPIPS loss: 0.0176 | MSE loss: 0.0003
# Epoch 346 | LPIPS loss: 0.0179 | MSE loss: 0.0003
# Epoch 347 | LPIPS loss: 0.0174 | MSE loss: 0.0003
# Epoch 348 | LPIPS loss: 0.0171 | MSE loss: 0.0003
# Epoch 349 | LPIPS loss: 0.0174 | MSE loss: 0.0003
# Epoch 350 | LPIPS loss: 0.0171 | MSE loss: 0.0002
# Epoch 351 | LPIPS loss: 0.0172 | MSE loss: 0.0002
# Epoch 352 | LPIPS loss: 0.0173 | MSE loss: 0.0002
# Epoch 353 | LPIPS loss: 0.0169 | MSE loss: 0.0002
# Epoch 354 | LPIPS loss: 0.0169 | MSE loss: 0.0002
# Epoch 355 | LPIPS loss: 0.0175 | MSE loss: 0.0003
# Epoch 356 | LPIPS loss: 0.0174 | MSE loss: 0.0003
# Epoch 357 | LPIPS loss: 0.0175 | MSE loss: 0.0003
# Epoch 358 | LPIPS loss: 0.0181 | MSE loss: 0.0002
# Epoch 359 | LPIPS loss: 0.0186 | MSE loss: 0.0002
# Epoch 360 | LPIPS loss: 0.0185 | MSE loss: 0.0002
# Epoch 361 | LPIPS loss: 0.0231 | MSE loss: 0.0002
# Epoch 362 | LPIPS loss: 0.0544 | MSE loss: 0.0002
# Epoch 363 | LPIPS loss: 0.0217 | MSE loss: 0.0002
# Epoch 364 | LPIPS loss: 0.0180 | MSE loss: 0.0002
# Epoch 365 | LPIPS loss: 0.0172 | MSE loss: 0.0002
# Epoch 366 | LPIPS loss: 0.0167 | MSE loss: 0.0002
# Epoch 367 | LPIPS loss: 0.0165 | MSE loss: 0.0002
# Epoch 368 | LPIPS loss: 0.0163 | MSE loss: 0.0002
# Epoch 369 | LPIPS loss: 0.0162 | MSE loss: 0.0002
# Epoch 370 | LPIPS loss: 0.0161 | MSE loss: 0.0003
# Epoch 371 | LPIPS loss: 0.0160 | MSE loss: 0.0003
# Epoch 372 | LPIPS loss: 0.0160 | MSE loss: 0.0002
# Epoch 373 | LPIPS loss: 0.0159 | MSE loss: 0.0002
# Epoch 374 | LPIPS loss: 0.0158 | MSE loss: 0.0002
# Epoch 375 | LPIPS loss: 0.0158 | MSE loss: 0.0002
# Epoch 376 | LPIPS loss: 0.0159 | MSE loss: 0.0002
# Epoch 377 | LPIPS loss: 0.0158 | MSE loss: 0.0002
# Epoch 378 | LPIPS loss: 0.0158 | MSE loss: 0.0002
# Epoch 379 | LPIPS loss: 0.0156 | MSE loss: 0.0002
# Epoch 380 | LPIPS loss: 0.0156 | MSE loss: 0.0002
# Epoch 381 | LPIPS loss: 0.0154 | MSE loss: 0.0003
# Epoch 382 | LPIPS loss: 0.0155 | MSE loss: 0.0003
# Epoch 383 | LPIPS loss: 0.0155 | MSE loss: 0.0002
# Epoch 384 | LPIPS loss: 0.0155 | MSE loss: 0.0002
# Epoch 385 | LPIPS loss: 0.0154 | MSE loss: 0.0002
# Epoch 386 | LPIPS loss: 0.0153 | MSE loss: 0.0002
# Epoch 387 | LPIPS loss: 0.0154 | MSE loss: 0.0002
# Epoch 388 | LPIPS loss: 0.0157 | MSE loss: 0.0002
# Epoch 389 | LPIPS loss: 0.0153 | MSE loss: 0.0002
# Epoch 390 | LPIPS loss: 0.0151 | MSE loss: 0.0002
# Epoch 391 | LPIPS loss: 0.0152 | MSE loss: 0.0002
# Epoch 392 | LPIPS loss: 0.0151 | MSE loss: 0.0002
# Epoch 393 | LPIPS loss: 0.0149 | MSE loss: 0.0002
# Epoch 394 | LPIPS loss: 0.0149 | MSE loss: 0.0002
# Epoch 395 | LPIPS loss: 0.0150 | MSE loss: 0.0002
# Epoch 396 | LPIPS loss: 0.0152 | MSE loss: 0.0002
# Epoch 397 | LPIPS loss: 0.0151 | MSE loss: 0.0002
# Epoch 398 | LPIPS loss: 0.0148 | MSE loss: 0.0002
# Epoch 399 | LPIPS loss: 0.0157 | MSE loss: 0.0002
# Epoch 400 | LPIPS loss: 0.0162 | MSE loss: 0.0002
# Epoch 401 | LPIPS loss: 0.0150 | MSE loss: 0.0002
# Epoch 402 | LPIPS loss: 0.0149 | MSE loss: 0.0002
# Epoch 403 | LPIPS loss: 0.0150 | MSE loss: 0.0002
# Epoch 404 | LPIPS loss: 0.0148 | MSE loss: 0.0002
# Epoch 405 | LPIPS loss: 0.0147 | MSE loss: 0.0002
# Epoch 406 | LPIPS loss: 0.0146 | MSE loss: 0.0002
# Epoch 407 | LPIPS loss: 0.0147 | MSE loss: 0.0002
# Epoch 408 | LPIPS loss: 0.0153 | MSE loss: 0.0002
# Epoch 409 | LPIPS loss: 0.0149 | MSE loss: 0.0002
# Epoch 410 | LPIPS loss: 0.0147 | MSE loss: 0.0002
# Epoch 411 | LPIPS loss: 0.0146 | MSE loss: 0.0002
# Epoch 412 | LPIPS loss: 0.0144 | MSE loss: 0.0002
# Epoch 413 | LPIPS loss: 0.0143 | MSE loss: 0.0002
# Epoch 414 | LPIPS loss: 0.0143 | MSE loss: 0.0002
# Epoch 415 | LPIPS loss: 0.0146 | MSE loss: 0.0002
# Epoch 416 | LPIPS loss: 0.0143 | MSE loss: 0.0003
# Epoch 417 | LPIPS loss: 0.0146 | MSE loss: 0.0004
# Epoch 418 | LPIPS loss: 0.0149 | MSE loss: 0.0002
# Epoch 419 | LPIPS loss: 0.0142 | MSE loss: 0.0002
# Epoch 420 | LPIPS loss: 0.0144 | MSE loss: 0.0002
# Epoch 421 | LPIPS loss: 0.0142 | MSE loss: 0.0002
# Epoch 422 | LPIPS loss: 0.0142 | MSE loss: 0.0002
# Epoch 423 | LPIPS loss: 0.0147 | MSE loss: 0.0002
# Epoch 424 | LPIPS loss: 0.0206 | MSE loss: 0.0002
# Epoch 425 | LPIPS loss: 0.0159 | MSE loss: 0.0002
# Epoch 426 | LPIPS loss: 0.0149 | MSE loss: 0.0002
# Epoch 427 | LPIPS loss: 0.0144 | MSE loss: 0.0002
# Epoch 428 | LPIPS loss: 0.0139 | MSE loss: 0.0002
# Epoch 429 | LPIPS loss: 0.0138 | MSE loss: 0.0002
# Epoch 430 | LPIPS loss: 0.0137 | MSE loss: 0.0002
# Epoch 431 | LPIPS loss: 0.0137 | MSE loss: 0.0002
# Epoch 432 | LPIPS loss: 0.0139 | MSE loss: 0.0002
# Epoch 433 | LPIPS loss: 0.0139 | MSE loss: 0.0002
# Epoch 434 | LPIPS loss: 0.0137 | MSE loss: 0.0002
# Epoch 435 | LPIPS loss: 0.0137 | MSE loss: 0.0002
# Epoch 436 | LPIPS loss: 0.0138 | MSE loss: 0.0002
# Epoch 437 | LPIPS loss: 0.0143 | MSE loss: 0.0002
# Epoch 438 | LPIPS loss: 0.0137 | MSE loss: 0.0002
# Epoch 439 | LPIPS loss: 0.0137 | MSE loss: 0.0002
# Epoch 440 | LPIPS loss: 0.0136 | MSE loss: 0.0002
# Epoch 441 | LPIPS loss: 0.0136 | MSE loss: 0.0002
# Epoch 442 | LPIPS loss: 0.0138 | MSE loss: 0.0002
# Epoch 443 | LPIPS loss: 0.0140 | MSE loss: 0.0002
# Epoch 444 | LPIPS loss: 0.0138 | MSE loss: 0.0002
# Epoch 445 | LPIPS loss: 0.0316 | MSE loss: 0.0002
# Epoch 446 | LPIPS loss: 0.0382 | MSE loss: 0.0002
# Epoch 447 | LPIPS loss: 0.0196 | MSE loss: 0.0002
# Epoch 448 | LPIPS loss: 0.0163 | MSE loss: 0.0002
# Epoch 449 | LPIPS loss: 0.0144 | MSE loss: 0.0002
# Epoch 450 | LPIPS loss: 0.0138 | MSE loss: 0.0002
# Epoch 451 | LPIPS loss: 0.0135 | MSE loss: 0.0002
# Epoch 452 | LPIPS loss: 0.0135 | MSE loss: 0.0002
# Epoch 453 | LPIPS loss: 0.0133 | MSE loss: 0.0002
# Epoch 454 | LPIPS loss: 0.0131 | MSE loss: 0.0002
# Epoch 455 | LPIPS loss: 0.0131 | MSE loss: 0.0002
# Epoch 456 | LPIPS loss: 0.0132 | MSE loss: 0.0002
# Epoch 457 | LPIPS loss: 0.0133 | MSE loss: 0.0002
# Epoch 458 | LPIPS loss: 0.0130 | MSE loss: 0.0002
# Epoch 459 | LPIPS loss: 0.0129 | MSE loss: 0.0003
# Epoch 460 | LPIPS loss: 0.0129 | MSE loss: 0.0002
# Epoch 461 | LPIPS loss: 0.0129 | MSE loss: 0.0002
# Epoch 462 | LPIPS loss: 0.0130 | MSE loss: 0.0002
# Epoch 463 | LPIPS loss: 0.0131 | MSE loss: 0.0002
# Epoch 464 | LPIPS loss: 0.0128 | MSE loss: 0.0002
# Epoch 465 | LPIPS loss: 0.0129 | MSE loss: 0.0002
# Epoch 466 | LPIPS loss: 0.0129 | MSE loss: 0.0002
# Epoch 467 | LPIPS loss: 0.0128 | MSE loss: 0.0002
# Epoch 468 | LPIPS loss: 0.0127 | MSE loss: 0.0002
# Epoch 469 | LPIPS loss: 0.0127 | MSE loss: 0.0002
# Epoch 470 | LPIPS loss: 0.0127 | MSE loss: 0.0002
# Epoch 471 | LPIPS loss: 0.0127 | MSE loss: 0.0002
# Epoch 472 | LPIPS loss: 0.0126 | MSE loss: 0.0002
# Epoch 473 | LPIPS loss: 0.0127 | MSE loss: 0.0002
# Epoch 474 | LPIPS loss: 0.0126 | MSE loss: 0.0002
# Epoch 475 | LPIPS loss: 0.0126 | MSE loss: 0.0003
# Epoch 476 | LPIPS loss: 0.0126 | MSE loss: 0.0003
# Epoch 477 | LPIPS loss: 0.0126 | MSE loss: 0.0002
# Epoch 478 | LPIPS loss: 0.0125 | MSE loss: 0.0002
# Epoch 479 | LPIPS loss: 0.0124 | MSE loss: 0.0002
# Epoch 480 | LPIPS loss: 0.0123 | MSE loss: 0.0002
# Epoch 481 | LPIPS loss: 0.0124 | MSE loss: 0.0002
# Epoch 482 | LPIPS loss: 0.0123 | MSE loss: 0.0002
# Epoch 483 | LPIPS loss: 0.0123 | MSE loss: 0.0002
# Epoch 484 | LPIPS loss: 0.0123 | MSE loss: 0.0002
# Epoch 485 | LPIPS loss: 0.0126 | MSE loss: 0.0002
# Epoch 486 | LPIPS loss: 0.0123 | MSE loss: 0.0002
# Epoch 487 | LPIPS loss: 0.0122 | MSE loss: 0.0002
# Epoch 488 | LPIPS loss: 0.0126 | MSE loss: 0.0002
# Epoch 489 | LPIPS loss: 0.0123 | MSE loss: 0.0002
# Epoch 490 | LPIPS loss: 0.0122 | MSE loss: 0.0002
# Epoch 491 | LPIPS loss: 0.0123 | MSE loss: 0.0002
# Epoch 492 | LPIPS loss: 0.0121 | MSE loss: 0.0002
# Epoch 493 | LPIPS loss: 0.0121 | MSE loss: 0.0002
# Epoch 494 | LPIPS loss: 0.0124 | MSE loss: 0.0002
# Epoch 495 | LPIPS loss: 0.0121 | MSE loss: 0.0002
# Epoch 496 | LPIPS loss: 0.0120 | MSE loss: 0.0002
# Epoch 497 | LPIPS loss: 0.0121 | MSE loss: 0.0002
# Epoch 498 | LPIPS loss: 0.0121 | MSE loss: 0.0002
# Epoch 499 | LPIPS loss: 0.0122 | MSE loss: 0.0002
# Epoch 500 | LPIPS loss: 0.0122 | MSE loss: 0.0002
#      epoch  lpips_train_loss  mse_train_loss
# 0        1          0.815653        0.060523
# 1        2          0.812815        0.059908
# 2        3          0.799319        0.057852
# 3        4          0.750566        0.049430
# 4        5          0.733219        0.027049
# ..     ...               ...             ...
# 495    496          0.011979        0.000185
# 496    497          0.012116        0.000177
# 497    498          0.012106        0.000172
# 498    499          0.012232        0.000174
# 499    500          0.012173        0.000170
#
# [500 rows x 3 columns]

# %%
# Plot training curves.
plt.figure(figsize=(8, 4))
plt.plot(history_df["epoch"], history_df["lpips_train_loss"], marker="o", label="LPIPS-trained")
plt.plot(history_df["epoch"], history_df["mse_train_loss"], marker="o", label="MSE-trained")
plt.xlabel("Epoch")
plt.ylabel("Training loss")
plt.title(f"Training curves | {DATASET_NAME} | class={CLASS_NAME} | degradation={DEGRADATION}")
plt.legend()
plt.show()

# %%
metrics = evaluate_models(model_lpips, model_mse, val_loader, lpips_loss, mse_loss)
metrics
# Out:
#                        value
# lpips_model_lpips   0.013458
# mse_model_lpips     0.034459
# lpips_model_mse     0.000517
# mse_model_mse       0.000183
# lpips_model_psnr   33.569558
# mse_model_psnr     37.931554

# %%
show_reconstructions(
    model_lpips,
    model_mse,
    val_loader,
    title=f"{DATASET_NAME} | class={CLASS_NAME} | size={IMAGE_SIZE} | degradation={DEGRADATION}",
)

# %%
# Cross-metric bar chart: one model can win on LPIPS but lose on MSE.
plot_df = pd.DataFrame({
    "metric": ["LPIPS score", "MSE score", "PSNR"],
    "LPIPS-trained": [metrics.loc["lpips_model_lpips", "value"], metrics.loc["lpips_model_mse", "value"], metrics.loc["lpips_model_psnr", "value"]],
    "MSE-trained": [metrics.loc["mse_model_lpips", "value"], metrics.loc["mse_model_mse", "value"], metrics.loc["mse_model_psnr", "value"]],
})
plot_df = plot_df.melt(id_vars="metric", var_name="model", value_name="value")
plt.figure(figsize=(8, 4))
sns.barplot(data=plot_df, x="metric", y="value", hue="model")
plt.title("Cross-metric comparison")
plt.show()

# %% [markdown]
# ## Notes
#
# - If LPIPS looks worse on `32x32` or on exact identity reconstruction, that does not necessarily mean LPIPS is bad.
# - It often means that pixel-exact matching is easier for MSE, while LPIPS is trying to measure perceptual similarity through deep features.
# - Try changing `DEGRADATION` from `identity` to `blur` or `downsample` and compare again.
