# %% [markdown]
# # 03. LPIPS Class-wise Analysis: Frog, Horse, and More
#
# This notebook compares several semantic classes.
#
# Questions answered here:
#
# - Does LPIPS behave differently on different object classes?
# - Are frog and horse more or less LPIPS-friendly than cat or ship?

# %%
# !pip install torch torchvision lpips matplotlib pandas pillow seaborn

import os
import math
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from torch.utils.data import DataLoader, Dataset, Subset

import lpips

sns.set_theme(style="whitegrid")
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / "data"
FIG_DIR = BASE_DIR / "generated_figures"
FIG_DIR.mkdir(exist_ok=True)
print("Using device:", DEVICE)
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.25.0+cu128)
# Requirement already satisfied: lpips in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.3)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Using device: cuda

# %%
# Reproducibility helps make LPIPS-vs-MSE comparisons fair.
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)

CIFAR10_CLASSES = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]
STL10_CLASSES = CIFAR10_CLASSES

class ConvAutoencoder(nn.Module):
    """Small convolutional autoencoder used across the notebooks."""
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, 3, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 128, 3, stride=2, padding=1),
            nn.ReLU(inplace=True),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 3, 3, padding=1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.decoder(self.encoder(x))


def to_lpips_range(x: torch.Tensor) -> torch.Tensor:
    # LPIPS expects images in [-1, 1].
    return x * 2.0 - 1.0


def psnr(pred: torch.Tensor, target: torch.Tensor) -> torch.Tensor:
    mse = torch.mean((pred - target) ** 2, dim=(1, 2, 3))
    return 10.0 * torch.log10(1.0 / (mse + 1e-8))


def build_transform(image_size: int):
    return T.Compose([
        T.Resize((image_size, image_size)),
        T.ToTensor(),
    ])


def degrade_image(image: torch.Tensor, mode: str) -> torch.Tensor:
    image = image.clone()
    if mode == "identity":
        return image
    if mode == "gaussian_noise":
        noise = 0.08 * torch.randn_like(image)
        return torch.clamp(image + noise, 0.0, 1.0)
    if mode == "blur":
        return TF.gaussian_blur(image, kernel_size=[5, 5], sigma=[1.2, 1.2])
    if mode == "downsample":
        h, w = image.shape[-2:]
        small = TF.resize(image, [max(8, h // 4), max(8, w // 4)], antialias=True)
        return TF.resize(small, [h, w], antialias=True)
    if mode == "shift":
        # Small spatial shift is useful because LPIPS and MSE can react differently.
        return torch.roll(image, shifts=(2, 2), dims=(1, 2))
    raise ValueError(f"Unknown degradation mode: {mode}")


class ReconstructionWrapper(Dataset):
    def __init__(self, base_dataset, degradation="identity"):
        self.base_dataset = base_dataset
        self.degradation = degradation

    def __len__(self):
        return len(self.base_dataset)

    def __getitem__(self, idx):
        sample = self.base_dataset[idx]
        image = sample[0] if isinstance(sample, tuple) else sample
        degraded = degrade_image(image, self.degradation)
        return degraded, image


class RepeatedSingleImageDataset(Dataset):
    def __init__(self, image: torch.Tensor, repeats: int = 256, degradation: str = "identity"):
        self.image = image
        self.repeats = repeats
        self.degradation = degradation

    def __len__(self):
        return self.repeats

    def __getitem__(self, idx):
        degraded = degrade_image(self.image, self.degradation)
        return degraded, self.image


def get_dataset(dataset_name: str, image_size: int):
    transform = build_transform(image_size)
    name = dataset_name.upper()
    if name == "CIFAR10":
        return torchvision.datasets.CIFAR10(root=str(DATA_DIR), train=True, download=True, transform=transform)
    if name == "CIFAR100":
        return torchvision.datasets.CIFAR100(root=str(DATA_DIR), train=True, download=True, transform=transform)
    if name == "STL10":
        return torchvision.datasets.STL10(root=str(DATA_DIR), split="train", download=True, transform=transform)
    if name == "CELEBA":
        return torchvision.datasets.CelebA(root=str(DATA_DIR), split="train", download=True, transform=transform)
    raise ValueError(f"Unsupported dataset: {dataset_name}")


def get_targets(dataset):
    if hasattr(dataset, "targets"):
        return [int(x) for x in dataset.targets]
    if hasattr(dataset, "labels"):
        return [int(x) for x in dataset.labels]
    return None


def filter_by_class(dataset, dataset_name: str, class_name: str, max_items: int = 1000):
    if class_name == "all":
        return dataset
    targets = get_targets(dataset)
    if targets is None:
        raise ValueError(f"Dataset {dataset_name} does not expose simple class labels for filtering.")
    if dataset_name.upper() == "CIFAR10":
        class_index = CIFAR10_CLASSES.index(class_name)
    elif dataset_name.upper() == "STL10":
        class_index = STL10_CLASSES.index(class_name)
    else:
        raise ValueError(f"Class filtering not set up for {dataset_name}.")
    indices = [i for i, target in enumerate(targets) if target == class_index][:max_items]
    return Subset(dataset, indices)


def train_two_models(train_loader, epochs=5, lpips_net="vgg"):
    base_model = ConvAutoencoder().to(DEVICE)
    model_lpips = ConvAutoencoder().to(DEVICE)
    model_mse = ConvAutoencoder().to(DEVICE)
    model_lpips.load_state_dict(base_model.state_dict())
    model_mse.load_state_dict(base_model.state_dict())

    optimizer_lpips = optim.Adam(model_lpips.parameters(), lr=1e-4)
    optimizer_mse = optim.Adam(model_mse.parameters(), lr=1e-4)
    lpips_loss = lpips.LPIPS(net=lpips_net).to(DEVICE).eval()
    mse_loss = nn.MSELoss()

    history = {"epoch": [], "lpips_train_loss": [], "mse_train_loss": []}

    for epoch in range(1, epochs + 1):
        model_lpips.train()
        model_mse.train()
        running_lpips = 0.0
        running_mse = 0.0
        batches = 0

        for degraded, clean in train_loader:
            degraded = degraded.to(DEVICE)
            clean = clean.to(DEVICE)

            optimizer_lpips.zero_grad()
            pred_lpips = model_lpips(degraded)
            loss_lp = lpips_loss(to_lpips_range(pred_lpips), to_lpips_range(clean)).mean()
            loss_lp.backward()
            optimizer_lpips.step()

            optimizer_mse.zero_grad()
            pred_mse = model_mse(degraded)
            loss_mse = mse_loss(pred_mse, clean)
            loss_mse.backward()
            optimizer_mse.step()

            running_lpips += loss_lp.item()
            running_mse += loss_mse.item()
            batches += 1

        history["epoch"].append(epoch)
        history["lpips_train_loss"].append(running_lpips / batches)
        history["mse_train_loss"].append(running_mse / batches)
        print(f"Epoch {epoch:02d} | LPIPS loss: {history['lpips_train_loss'][-1]:.4f} | MSE loss: {history['mse_train_loss'][-1]:.4f}")

    return model_lpips, model_mse, pd.DataFrame(history), lpips_loss, mse_loss


def evaluate_models(model_lpips, model_mse, loader, lpips_loss, mse_loss):
    model_lpips.eval()
    model_mse.eval()
    rows = []

    with torch.no_grad():
        for degraded, clean in loader:
            degraded = degraded.to(DEVICE)
            clean = clean.to(DEVICE)
            pred_lpips = model_lpips(degraded)
            pred_mse = model_mse(degraded)

            rows.append({
                "lpips_model_lpips": lpips_loss(to_lpips_range(pred_lpips), to_lpips_range(clean)).mean().item(),
                "mse_model_lpips": lpips_loss(to_lpips_range(pred_mse), to_lpips_range(clean)).mean().item(),
                "lpips_model_mse": mse_loss(pred_lpips, clean).item(),
                "mse_model_mse": mse_loss(pred_mse, clean).item(),
                "lpips_model_psnr": psnr(pred_lpips, clean).mean().item(),
                "mse_model_psnr": psnr(pred_mse, clean).mean().item(),
            })
    return pd.DataFrame(rows).mean().to_frame(name="value")


def show_reconstructions(model_lpips, model_mse, loader, title, n=5):
    degraded, clean = next(iter(loader))
    degraded = degraded.to(DEVICE)
    clean = clean.to(DEVICE)
    with torch.no_grad():
        pred_lpips = model_lpips(degraded).cpu()
        pred_mse = model_mse(degraded).cpu()
    degraded = degraded.cpu()
    clean = clean.cpu()

    n = min(n, degraded.size(0))
    plt.figure(figsize=(3 * n, 8))
    for i in range(n):
        plt.subplot(4, n, i + 1)
        plt.imshow(degraded[i].permute(1, 2, 0))
        plt.title("Input")
        plt.axis("off")

        plt.subplot(4, n, n + i + 1)
        plt.imshow(clean[i].permute(1, 2, 0))
        plt.title("Target")
        plt.axis("off")

        plt.subplot(4, n, 2 * n + i + 1)
        plt.imshow(pred_lpips[i].permute(1, 2, 0))
        plt.title("LPIPS")
        plt.axis("off")

        plt.subplot(4, n, 3 * n + i + 1)
        plt.imshow(pred_mse[i].permute(1, 2, 0))
        plt.title("MSE")
        plt.axis("off")

    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

# %%
DATASET_NAME = "CIFAR10"
CLASSES_TO_TEST = ["frog", "horse", "cat", "ship"]
IMAGE_SIZE = 64
DEGRADATION = "identity"
TRAIN_SAMPLES = 256
VAL_SAMPLES = 64
BATCH_SIZE = 32
EPOCHS = 100
LPIPS_NET = "vgg"

# %%
class_rows = []
reconstruction_cache = {}

for class_name in CLASSES_TO_TEST:
    print("\nRunning class:", class_name)
    dataset = get_dataset(DATASET_NAME, IMAGE_SIZE)
    dataset = filter_by_class(dataset, DATASET_NAME, class_name, max_items=TRAIN_SAMPLES + VAL_SAMPLES)

    indices = dataset.indices
    root_dataset = dataset.dataset
    train_indices = indices[:TRAIN_SAMPLES]
    val_indices = indices[TRAIN_SAMPLES:TRAIN_SAMPLES + VAL_SAMPLES]
    if len(val_indices) == 0:
        val_indices = indices[:min(VAL_SAMPLES, len(indices))]

    train_dataset = ReconstructionWrapper(Subset(root_dataset, train_indices), degradation=DEGRADATION)
    val_dataset = ReconstructionWrapper(Subset(root_dataset, val_indices), degradation=DEGRADATION)
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

    model_lpips, model_mse, history_df, lpips_loss, mse_loss = train_two_models(train_loader, epochs=EPOCHS, lpips_net=LPIPS_NET)
    metrics = evaluate_models(model_lpips, model_mse, val_loader, lpips_loss, mse_loss)

    class_rows.append({
        "class_name": class_name,
        "lpips_model_lpips": metrics.loc["lpips_model_lpips", "value"],
        "mse_model_lpips": metrics.loc["mse_model_lpips", "value"],
        "lpips_model_mse": metrics.loc["lpips_model_mse", "value"],
        "mse_model_mse": metrics.loc["mse_model_mse", "value"],
        "lpips_model_psnr": metrics.loc["lpips_model_psnr", "value"],
        "mse_model_psnr": metrics.loc["mse_model_psnr", "value"],
    })

    reconstruction_cache[class_name] = (model_lpips, model_mse, val_loader)

class_df = pd.DataFrame(class_rows)
class_df
# Out:
# Running class: frog
# 100%|██████████| 170M/170M [00:22<00:00, 7.61MB/s]
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:03<00:00, 172MB/s]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Epoch 01 | LPIPS loss: 0.8364 | MSE loss: 0.0571
# Epoch 02 | LPIPS loss: 0.8349 | MSE loss: 0.0568
# Epoch 03 | LPIPS loss: 0.8330 | MSE loss: 0.0562
# Epoch 04 | LPIPS loss: 0.8301 | MSE loss: 0.0553
# Epoch 05 | LPIPS loss: 0.8173 | MSE loss: 0.0533
# Epoch 06 | LPIPS loss: 0.7613 | MSE loss: 0.0511
# Epoch 07 | LPIPS loss: 0.7431 | MSE loss: 0.0494
# Epoch 08 | LPIPS loss: 0.7343 | MSE loss: 0.0473
# Epoch 09 | LPIPS loss: 0.7281 | MSE loss: 0.0441
# Epoch 10 | LPIPS loss: 0.7213 | MSE loss: 0.0378
# Epoch 11 | LPIPS loss: 0.7136 | MSE loss: 0.0292
# Epoch 12 | LPIPS loss: 0.7022 | MSE loss: 0.0232
# Epoch 13 | LPIPS loss: 0.6886 | MSE loss: 0.0209
# Epoch 14 | LPIPS loss: 0.6777 | MSE loss: 0.0191
# Epoch 15 | LPIPS loss: 0.6677 | MSE loss: 0.0169
# Epoch 16 | LPIPS loss: 0.6587 | MSE loss: 0.0144
# Epoch 17 | LPIPS loss: 0.6503 | MSE loss: 0.0125
# Epoch 18 | LPIPS loss: 0.6428 | MSE loss: 0.0111
# Epoch 19 | LPIPS loss: 0.6352 | MSE loss: 0.0104
# Epoch 20 | LPIPS loss: 0.6263 | MSE loss: 0.0097
# Epoch 21 | LPIPS loss: 0.6155 | MSE loss: 0.0094
# Epoch 22 | LPIPS loss: 0.6034 | MSE loss: 0.0092
# Epoch 23 | LPIPS loss: 0.5893 | MSE loss: 0.0089
# Epoch 24 | LPIPS loss: 0.5743 | MSE loss: 0.0086
# Epoch 25 | LPIPS loss: 0.5563 | MSE loss: 0.0084
# Epoch 26 | LPIPS loss: 0.5354 | MSE loss: 0.0082
# Epoch 27 | LPIPS loss: 0.5120 | MSE loss: 0.0080
# Epoch 28 | LPIPS loss: 0.4878 | MSE loss: 0.0078
# Epoch 29 | LPIPS loss: 0.4654 | MSE loss: 0.0076
# Epoch 30 | LPIPS loss: 0.4455 | MSE loss: 0.0075
# Epoch 31 | LPIPS loss: 0.4282 | MSE loss: 0.0073
# Epoch 32 | LPIPS loss: 0.4119 | MSE loss: 0.0071
# Epoch 33 | LPIPS loss: 0.3976 | MSE loss: 0.0069
# Epoch 34 | LPIPS loss: 0.3845 | MSE loss: 0.0068
# Epoch 35 | LPIPS loss: 0.3722 | MSE loss: 0.0066
# Epoch 36 | LPIPS loss: 0.3608 | MSE loss: 0.0065
# Epoch 37 | LPIPS loss: 0.3500 | MSE loss: 0.0064
# Epoch 38 | LPIPS loss: 0.3406 | MSE loss: 0.0062
# Epoch 39 | LPIPS loss: 0.3330 | MSE loss: 0.0060
# Epoch 40 | LPIPS loss: 0.3248 | MSE loss: 0.0059
# Epoch 41 | LPIPS loss: 0.3181 | MSE loss: 0.0057
# Epoch 42 | LPIPS loss: 0.3115 | MSE loss: 0.0056
# Epoch 43 | LPIPS loss: 0.3055 | MSE loss: 0.0055
# Epoch 44 | LPIPS loss: 0.3000 | MSE loss: 0.0054
# Epoch 45 | LPIPS loss: 0.2945 | MSE loss: 0.0053
# Epoch 46 | LPIPS loss: 0.2881 | MSE loss: 0.0052
# Epoch 47 | LPIPS loss: 0.2936 | MSE loss: 0.0051
# Epoch 48 | LPIPS loss: 0.2760 | MSE loss: 0.0050
# Epoch 49 | LPIPS loss: 0.2669 | MSE loss: 0.0050
# Epoch 50 | LPIPS loss: 0.2572 | MSE loss: 0.0049
# Epoch 51 | LPIPS loss: 0.2492 | MSE loss: 0.0049
# Epoch 52 | LPIPS loss: 0.2430 | MSE loss: 0.0047
# Epoch 53 | LPIPS loss: 0.2380 | MSE loss: 0.0047
# Epoch 54 | LPIPS loss: 0.2326 | MSE loss: 0.0046
# Epoch 55 | LPIPS loss: 0.2282 | MSE loss: 0.0045
# Epoch 56 | LPIPS loss: 0.2238 | MSE loss: 0.0045
# Epoch 57 | LPIPS loss: 0.2201 | MSE loss: 0.0044
# Epoch 58 | LPIPS loss: 0.2164 | MSE loss: 0.0043
# Epoch 59 | LPIPS loss: 0.2129 | MSE loss: 0.0042
# Epoch 60 | LPIPS loss: 0.2096 | MSE loss: 0.0042
# Epoch 61 | LPIPS loss: 0.2060 | MSE loss: 0.0041
# Epoch 62 | LPIPS loss: 0.2029 | MSE loss: 0.0040
# Epoch 63 | LPIPS loss: 0.1996 | MSE loss: 0.0039
# Epoch 64 | LPIPS loss: 0.1961 | MSE loss: 0.0038
# Epoch 65 | LPIPS loss: 0.1931 | MSE loss: 0.0038
# Epoch 66 | LPIPS loss: 0.1914 | MSE loss: 0.0037
# Epoch 67 | LPIPS loss: 0.1889 | MSE loss: 0.0036
# Epoch 68 | LPIPS loss: 0.1861 | MSE loss: 0.0035
# Epoch 69 | LPIPS loss: 0.1828 | MSE loss: 0.0034
# Epoch 70 | LPIPS loss: 0.1826 | MSE loss: 0.0033
# Epoch 71 | LPIPS loss: 0.1942 | MSE loss: 0.0032
# Epoch 72 | LPIPS loss: 0.1815 | MSE loss: 0.0032
# Epoch 73 | LPIPS loss: 0.1770 | MSE loss: 0.0031
# Epoch 74 | LPIPS loss: 0.1739 | MSE loss: 0.0030
# Epoch 75 | LPIPS loss: 0.1711 | MSE loss: 0.0030
# Epoch 76 | LPIPS loss: 0.1688 | MSE loss: 0.0030
# Epoch 77 | LPIPS loss: 0.1662 | MSE loss: 0.0029
# Epoch 78 | LPIPS loss: 0.1638 | MSE loss: 0.0029
# Epoch 79 | LPIPS loss: 0.1626 | MSE loss: 0.0028
# Epoch 80 | LPIPS loss: 0.1605 | MSE loss: 0.0028
# Epoch 81 | LPIPS loss: 0.1579 | MSE loss: 0.0028
# Epoch 82 | LPIPS loss: 0.1559 | MSE loss: 0.0027
# Epoch 83 | LPIPS loss: 0.1540 | MSE loss: 0.0027
# Epoch 84 | LPIPS loss: 0.1533 | MSE loss: 0.0027
# Epoch 85 | LPIPS loss: 0.1506 | MSE loss: 0.0026
# Epoch 86 | LPIPS loss: 0.1491 | MSE loss: 0.0026
# Epoch 87 | LPIPS loss: 0.1467 | MSE loss: 0.0026
# Epoch 88 | LPIPS loss: 0.1451 | MSE loss: 0.0027
# Epoch 89 | LPIPS loss: 0.1431 | MSE loss: 0.0026
# Epoch 90 | LPIPS loss: 0.1415 | MSE loss: 0.0025
# Epoch 91 | LPIPS loss: 0.1399 | MSE loss: 0.0026
# Epoch 92 | LPIPS loss: 0.1384 | MSE loss: 0.0025
# Epoch 93 | LPIPS loss: 0.1369 | MSE loss: 0.0025
# Epoch 94 | LPIPS loss: 0.1348 | MSE loss: 0.0025
# Epoch 95 | LPIPS loss: 0.1335 | MSE loss: 0.0024
# Epoch 96 | LPIPS loss: 0.1321 | MSE loss: 0.0024
# Epoch 97 | LPIPS loss: 0.1314 | MSE loss: 0.0024
# Epoch 98 | LPIPS loss: 0.1296 | MSE loss: 0.0024
# Epoch 99 | LPIPS loss: 0.1283 | MSE loss: 0.0023
# Epoch 100 | LPIPS loss: 0.1390 | MSE loss: 0.0023
#
# Running class: horse
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Epoch 01 | LPIPS loss: 0.7745 | MSE loss: 0.0577
# Epoch 02 | LPIPS loss: 0.7689 | MSE loss: 0.0575
# Epoch 03 | LPIPS loss: 0.7642 | MSE loss: 0.0571
# Epoch 04 | LPIPS loss: 0.7614 | MSE loss: 0.0565
# Epoch 05 | LPIPS loss: 0.7591 | MSE loss: 0.0550
# Epoch 06 | LPIPS loss: 0.7557 | MSE loss: 0.0516
# Epoch 07 | LPIPS loss: 0.7500 | MSE loss: 0.0440
# Epoch 08 | LPIPS loss: 0.7404 | MSE loss: 0.0327
# Epoch 09 | LPIPS loss: 0.7251 | MSE loss: 0.0210
# Epoch 10 | LPIPS loss: 0.7064 | MSE loss: 0.0155
# Epoch 11 | LPIPS loss: 0.6852 | MSE loss: 0.0129
# Epoch 12 | LPIPS loss: 0.6645 | MSE loss: 0.0113
# Epoch 13 | LPIPS loss: 0.6451 | MSE loss: 0.0108
# Epoch 14 | LPIPS loss: 0.6250 | MSE loss: 0.0103
# Epoch 15 | LPIPS loss: 0.5976 | MSE loss: 0.0100
# Epoch 16 | LPIPS loss: 0.5713 | MSE loss: 0.0097
# Epoch 17 | LPIPS loss: 0.5483 | MSE loss: 0.0095
# Epoch 18 | LPIPS loss: 0.5283 | MSE loss: 0.0092
# Epoch 19 | LPIPS loss: 0.5079 | MSE loss: 0.0090
# Epoch 20 | LPIPS loss: 0.4890 | MSE loss: 0.0088
# Epoch 21 | LPIPS loss: 0.4702 | MSE loss: 0.0086
# Epoch 22 | LPIPS loss: 0.4542 | MSE loss: 0.0085
# Epoch 23 | LPIPS loss: 0.4405 | MSE loss: 0.0083
# Epoch 24 | LPIPS loss: 0.4280 | MSE loss: 0.0081
# Epoch 25 | LPIPS loss: 0.4174 | MSE loss: 0.0079
# Epoch 26 | LPIPS loss: 0.4050 | MSE loss: 0.0078
# Epoch 27 | LPIPS loss: 0.3926 | MSE loss: 0.0077
# Epoch 28 | LPIPS loss: 0.3817 | MSE loss: 0.0076
# Epoch 29 | LPIPS loss: 0.3686 | MSE loss: 0.0074
# Epoch 30 | LPIPS loss: 0.3569 | MSE loss: 0.0072
# Epoch 31 | LPIPS loss: 0.3467 | MSE loss: 0.0070
# Epoch 32 | LPIPS loss: 0.3372 | MSE loss: 0.0069
# Epoch 33 | LPIPS loss: 0.3282 | MSE loss: 0.0068
# Epoch 34 | LPIPS loss: 0.3184 | MSE loss: 0.0067
# Epoch 35 | LPIPS loss: 0.3107 | MSE loss: 0.0066
# Epoch 36 | LPIPS loss: 0.3038 | MSE loss: 0.0065
# Epoch 37 | LPIPS loss: 0.2948 | MSE loss: 0.0064
# Epoch 38 | LPIPS loss: 0.2870 | MSE loss: 0.0063
# Epoch 39 | LPIPS loss: 0.2822 | MSE loss: 0.0061
# Epoch 40 | LPIPS loss: 0.2756 | MSE loss: 0.0060
# Epoch 41 | LPIPS loss: 0.2696 | MSE loss: 0.0060
# Epoch 42 | LPIPS loss: 0.2646 | MSE loss: 0.0059
# Epoch 43 | LPIPS loss: 0.2607 | MSE loss: 0.0058
# Epoch 44 | LPIPS loss: 0.2542 | MSE loss: 0.0057
# Epoch 45 | LPIPS loss: 0.2497 | MSE loss: 0.0056
# Epoch 46 | LPIPS loss: 0.2449 | MSE loss: 0.0055
# Epoch 47 | LPIPS loss: 0.2408 | MSE loss: 0.0054
# Epoch 48 | LPIPS loss: 0.2353 | MSE loss: 0.0053
# Epoch 49 | LPIPS loss: 0.2306 | MSE loss: 0.0052
# Epoch 50 | LPIPS loss: 0.2243 | MSE loss: 0.0050
# Epoch 51 | LPIPS loss: 0.2205 | MSE loss: 0.0048
# Epoch 52 | LPIPS loss: 0.2179 | MSE loss: 0.0046
# Epoch 53 | LPIPS loss: 0.2098 | MSE loss: 0.0045
# Epoch 54 | LPIPS loss: 0.2048 | MSE loss: 0.0043
# Epoch 55 | LPIPS loss: 0.2002 | MSE loss: 0.0041
# Epoch 56 | LPIPS loss: 0.1945 | MSE loss: 0.0039
# Epoch 57 | LPIPS loss: 0.1904 | MSE loss: 0.0038
# Epoch 58 | LPIPS loss: 0.1859 | MSE loss: 0.0037
# Epoch 59 | LPIPS loss: 0.1827 | MSE loss: 0.0036
# Epoch 60 | LPIPS loss: 0.1792 | MSE loss: 0.0035
# Epoch 61 | LPIPS loss: 0.1761 | MSE loss: 0.0034
# Epoch 62 | LPIPS loss: 0.1763 | MSE loss: 0.0033
# Epoch 63 | LPIPS loss: 0.1749 | MSE loss: 0.0033
# Epoch 64 | LPIPS loss: 0.1719 | MSE loss: 0.0032
# Epoch 65 | LPIPS loss: 0.1687 | MSE loss: 0.0031
# Epoch 66 | LPIPS loss: 0.1641 | MSE loss: 0.0031
# Epoch 67 | LPIPS loss: 0.1620 | MSE loss: 0.0031
# Epoch 68 | LPIPS loss: 0.1594 | MSE loss: 0.0030
# Epoch 69 | LPIPS loss: 0.1570 | MSE loss: 0.0030
# Epoch 70 | LPIPS loss: 0.1544 | MSE loss: 0.0030
# Epoch 71 | LPIPS loss: 0.1517 | MSE loss: 0.0029
# Epoch 72 | LPIPS loss: 0.1503 | MSE loss: 0.0029
# Epoch 73 | LPIPS loss: 0.1501 | MSE loss: 0.0029
# Epoch 74 | LPIPS loss: 0.1478 | MSE loss: 0.0029
# Epoch 75 | LPIPS loss: 0.1471 | MSE loss: 0.0029
# Epoch 76 | LPIPS loss: 0.1471 | MSE loss: 0.0028
# Epoch 77 | LPIPS loss: 0.1461 | MSE loss: 0.0028
# Epoch 78 | LPIPS loss: 0.1427 | MSE loss: 0.0027
# Epoch 79 | LPIPS loss: 0.1458 | MSE loss: 0.0027
# Epoch 80 | LPIPS loss: 0.1502 | MSE loss: 0.0027
# Epoch 81 | LPIPS loss: 0.1460 | MSE loss: 0.0027
# Epoch 82 | LPIPS loss: 0.1384 | MSE loss: 0.0027
# Epoch 83 | LPIPS loss: 0.1365 | MSE loss: 0.0027
# Epoch 84 | LPIPS loss: 0.1350 | MSE loss: 0.0026
# Epoch 85 | LPIPS loss: 0.1327 | MSE loss: 0.0026
# Epoch 86 | LPIPS loss: 0.1304 | MSE loss: 0.0026
# Epoch 87 | LPIPS loss: 0.1289 | MSE loss: 0.0026
# Epoch 88 | LPIPS loss: 0.1280 | MSE loss: 0.0026
# Epoch 89 | LPIPS loss: 0.1258 | MSE loss: 0.0026
# Epoch 90 | LPIPS loss: 0.1250 | MSE loss: 0.0025
# Epoch 91 | LPIPS loss: 0.1241 | MSE loss: 0.0025
# Epoch 92 | LPIPS loss: 0.1229 | MSE loss: 0.0025
# Epoch 93 | LPIPS loss: 0.1220 | MSE loss: 0.0025
# Epoch 94 | LPIPS loss: 0.1205 | MSE loss: 0.0024
# Epoch 95 | LPIPS loss: 0.1199 | MSE loss: 0.0024
# Epoch 96 | LPIPS loss: 0.1192 | MSE loss: 0.0024
# Epoch 97 | LPIPS loss: 0.1178 | MSE loss: 0.0024
# Epoch 98 | LPIPS loss: 0.1160 | MSE loss: 0.0024
# Epoch 99 | LPIPS loss: 0.1152 | MSE loss: 0.0024
# Epoch 100 | LPIPS loss: 0.1140 | MSE loss: 0.0024
#
# Running class: cat
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Epoch 01 | LPIPS loss: 0.7639 | MSE loss: 0.0635
# Epoch 02 | LPIPS loss: 0.7579 | MSE loss: 0.0632
# Epoch 03 | LPIPS loss: 0.7547 | MSE loss: 0.0628
# Epoch 04 | LPIPS loss: 0.7500 | MSE loss: 0.0619
# Epoch 05 | LPIPS loss: 0.7426 | MSE loss: 0.0600
# Epoch 06 | LPIPS loss: 0.7303 | MSE loss: 0.0567
# Epoch 07 | LPIPS loss: 0.7163 | MSE loss: 0.0521
# Epoch 08 | LPIPS loss: 0.7082 | MSE loss: 0.0454
# Epoch 09 | LPIPS loss: 0.7024 | MSE loss: 0.0358
# Epoch 10 | LPIPS loss: 0.6981 | MSE loss: 0.0246
# Epoch 11 | LPIPS loss: 0.6946 | MSE loss: 0.0171
# Epoch 12 | LPIPS loss: 0.6918 | MSE loss: 0.0150
# Epoch 13 | LPIPS loss: 0.6893 | MSE loss: 0.0133
# Epoch 14 | LPIPS loss: 0.6867 | MSE loss: 0.0121
# Epoch 15 | LPIPS loss: 0.6839 | MSE loss: 0.0115
# Epoch 16 | LPIPS loss: 0.6835 | MSE loss: 0.0110
# Epoch 17 | LPIPS loss: 0.6802 | MSE loss: 0.0105
# Epoch 18 | LPIPS loss: 0.6757 | MSE loss: 0.0102
# Epoch 19 | LPIPS loss: 0.6707 | MSE loss: 0.0100
# Epoch 20 | LPIPS loss: 0.6640 | MSE loss: 0.0098
# Epoch 21 | LPIPS loss: 0.6520 | MSE loss: 0.0096
# Epoch 22 | LPIPS loss: 0.6326 | MSE loss: 0.0095
# Epoch 23 | LPIPS loss: 0.6099 | MSE loss: 0.0093
# Epoch 24 | LPIPS loss: 0.5865 | MSE loss: 0.0091
# Epoch 25 | LPIPS loss: 0.5630 | MSE loss: 0.0090
# Epoch 26 | LPIPS loss: 0.5464 | MSE loss: 0.0088
# Epoch 27 | LPIPS loss: 0.5309 | MSE loss: 0.0087
# Epoch 28 | LPIPS loss: 0.5176 | MSE loss: 0.0085
# Epoch 29 | LPIPS loss: 0.5059 | MSE loss: 0.0084
# Epoch 30 | LPIPS loss: 0.4938 | MSE loss: 0.0082
# Epoch 31 | LPIPS loss: 0.4844 | MSE loss: 0.0081
# Epoch 32 | LPIPS loss: 0.4737 | MSE loss: 0.0080
# Epoch 33 | LPIPS loss: 0.4639 | MSE loss: 0.0079
# Epoch 34 | LPIPS loss: 0.4564 | MSE loss: 0.0078
# Epoch 35 | LPIPS loss: 0.4480 | MSE loss: 0.0077
# Epoch 36 | LPIPS loss: 0.4397 | MSE loss: 0.0076
# Epoch 37 | LPIPS loss: 0.4311 | MSE loss: 0.0075
# Epoch 38 | LPIPS loss: 0.4227 | MSE loss: 0.0074
# Epoch 39 | LPIPS loss: 0.4142 | MSE loss: 0.0072
# Epoch 40 | LPIPS loss: 0.4058 | MSE loss: 0.0072
# Epoch 41 | LPIPS loss: 0.3991 | MSE loss: 0.0071
# Epoch 42 | LPIPS loss: 0.3921 | MSE loss: 0.0069
# Epoch 43 | LPIPS loss: 0.3858 | MSE loss: 0.0069
# Epoch 44 | LPIPS loss: 0.3792 | MSE loss: 0.0068
# Epoch 45 | LPIPS loss: 0.3724 | MSE loss: 0.0068
# Epoch 46 | LPIPS loss: 0.3657 | MSE loss: 0.0067
# Epoch 47 | LPIPS loss: 0.3594 | MSE loss: 0.0066
# Epoch 48 | LPIPS loss: 0.3540 | MSE loss: 0.0066
# Epoch 49 | LPIPS loss: 0.3502 | MSE loss: 0.0064
# Epoch 50 | LPIPS loss: 0.3421 | MSE loss: 0.0064
# Epoch 51 | LPIPS loss: 0.3349 | MSE loss: 0.0063
# Epoch 52 | LPIPS loss: 0.3285 | MSE loss: 0.0062
# Epoch 53 | LPIPS loss: 0.3200 | MSE loss: 0.0062
# Epoch 54 | LPIPS loss: 0.3129 | MSE loss: 0.0061
# Epoch 55 | LPIPS loss: 0.3035 | MSE loss: 0.0062
# Epoch 56 | LPIPS loss: 0.2955 | MSE loss: 0.0061
# Epoch 57 | LPIPS loss: 0.2873 | MSE loss: 0.0061
# Epoch 58 | LPIPS loss: 0.2790 | MSE loss: 0.0060
# Epoch 59 | LPIPS loss: 0.2708 | MSE loss: 0.0060
# Epoch 60 | LPIPS loss: 0.2619 | MSE loss: 0.0060
# Epoch 61 | LPIPS loss: 0.2548 | MSE loss: 0.0059
# Epoch 62 | LPIPS loss: 0.2484 | MSE loss: 0.0060
# Epoch 63 | LPIPS loss: 0.2426 | MSE loss: 0.0059
# Epoch 64 | LPIPS loss: 0.2366 | MSE loss: 0.0058
# Epoch 65 | LPIPS loss: 0.2315 | MSE loss: 0.0057
# Epoch 66 | LPIPS loss: 0.2266 | MSE loss: 0.0056
# Epoch 67 | LPIPS loss: 0.2226 | MSE loss: 0.0056
# Epoch 68 | LPIPS loss: 0.2228 | MSE loss: 0.0055
# Epoch 69 | LPIPS loss: 0.2168 | MSE loss: 0.0055
# Epoch 70 | LPIPS loss: 0.2125 | MSE loss: 0.0054
# Epoch 71 | LPIPS loss: 0.2111 | MSE loss: 0.0054
# Epoch 72 | LPIPS loss: 0.2086 | MSE loss: 0.0053
# Epoch 73 | LPIPS loss: 0.2058 | MSE loss: 0.0053
# Epoch 74 | LPIPS loss: 0.2013 | MSE loss: 0.0053
# Epoch 75 | LPIPS loss: 0.1981 | MSE loss: 0.0052
# Epoch 76 | LPIPS loss: 0.1956 | MSE loss: 0.0052
# Epoch 77 | LPIPS loss: 0.1948 | MSE loss: 0.0051
# Epoch 78 | LPIPS loss: 0.1965 | MSE loss: 0.0051
# Epoch 79 | LPIPS loss: 0.1919 | MSE loss: 0.0050
# Epoch 80 | LPIPS loss: 0.1877 | MSE loss: 0.0050
# Epoch 81 | LPIPS loss: 0.1856 | MSE loss: 0.0049
# Epoch 82 | LPIPS loss: 0.1836 | MSE loss: 0.0049
# Epoch 83 | LPIPS loss: 0.1826 | MSE loss: 0.0048
# Epoch 84 | LPIPS loss: 0.1785 | MSE loss: 0.0048
# Epoch 85 | LPIPS loss: 0.1765 | MSE loss: 0.0048
# Epoch 86 | LPIPS loss: 0.1747 | MSE loss: 0.0047
# Epoch 87 | LPIPS loss: 0.1730 | MSE loss: 0.0045
# Epoch 88 | LPIPS loss: 0.1718 | MSE loss: 0.0044
# Epoch 89 | LPIPS loss: 0.1693 | MSE loss: 0.0042
# Epoch 90 | LPIPS loss: 0.1673 | MSE loss: 0.0042
# Epoch 91 | LPIPS loss: 0.1669 | MSE loss: 0.0040
# Epoch 92 | LPIPS loss: 0.1655 | MSE loss: 0.0038
# Epoch 93 | LPIPS loss: 0.1627 | MSE loss: 0.0037
# Epoch 94 | LPIPS loss: 0.1615 | MSE loss: 0.0035
# Epoch 95 | LPIPS loss: 0.1597 | MSE loss: 0.0032
# Epoch 96 | LPIPS loss: 0.1583 | MSE loss: 0.0031
# Epoch 97 | LPIPS loss: 0.1573 | MSE loss: 0.0030
# Epoch 98 | LPIPS loss: 0.1557 | MSE loss: 0.0028
# Epoch 99 | LPIPS loss: 0.1556 | MSE loss: 0.0027
# Epoch 100 | LPIPS loss: 0.1541 | MSE loss: 0.0026
#
# Running class: ship
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Epoch 01 | LPIPS loss: 0.7181 | MSE loss: 0.0586
# Epoch 02 | LPIPS loss: 0.7138 | MSE loss: 0.0584
# Epoch 03 | LPIPS loss: 0.7089 | MSE loss: 0.0579
# Epoch 04 | LPIPS loss: 0.7010 | MSE loss: 0.0566
# Epoch 05 | LPIPS loss: 0.6817 | MSE loss: 0.0538
# Epoch 06 | LPIPS loss: 0.6508 | MSE loss: 0.0485
# Epoch 07 | LPIPS loss: 0.6285 | MSE loss: 0.0453
# Epoch 08 | LPIPS loss: 0.6223 | MSE loss: 0.0413
# Epoch 09 | LPIPS loss: 0.6167 | MSE loss: 0.0366
# Epoch 10 | LPIPS loss: 0.6132 | MSE loss: 0.0318
# Epoch 11 | LPIPS loss: 0.6101 | MSE loss: 0.0275
# Epoch 12 | LPIPS loss: 0.6068 | MSE loss: 0.0234
# Epoch 13 | LPIPS loss: 0.6036 | MSE loss: 0.0196
# Epoch 14 | LPIPS loss: 0.6002 | MSE loss: 0.0164
# Epoch 15 | LPIPS loss: 0.5968 | MSE loss: 0.0138
# Epoch 16 | LPIPS loss: 0.5934 | MSE loss: 0.0119
# Epoch 17 | LPIPS loss: 0.5890 | MSE loss: 0.0107
# Epoch 18 | LPIPS loss: 0.5838 | MSE loss: 0.0100
# Epoch 19 | LPIPS loss: 0.5773 | MSE loss: 0.0096
# Epoch 20 | LPIPS loss: 0.5673 | MSE loss: 0.0093
# Epoch 21 | LPIPS loss: 0.5542 | MSE loss: 0.0091
# Epoch 22 | LPIPS loss: 0.5404 | MSE loss: 0.0088
# Epoch 23 | LPIPS loss: 0.5259 | MSE loss: 0.0086
# Epoch 24 | LPIPS loss: 0.5118 | MSE loss: 0.0085
# Epoch 25 | LPIPS loss: 0.4977 | MSE loss: 0.0083
# Epoch 26 | LPIPS loss: 0.4860 | MSE loss: 0.0082
# Epoch 27 | LPIPS loss: 0.4805 | MSE loss: 0.0080
# Epoch 28 | LPIPS loss: 0.4688 | MSE loss: 0.0080
# Epoch 29 | LPIPS loss: 0.4580 | MSE loss: 0.0078
# Epoch 30 | LPIPS loss: 0.4474 | MSE loss: 0.0076
# Epoch 31 | LPIPS loss: 0.4383 | MSE loss: 0.0075
# Epoch 32 | LPIPS loss: 0.4296 | MSE loss: 0.0074
# Epoch 33 | LPIPS loss: 0.4209 | MSE loss: 0.0073
# Epoch 34 | LPIPS loss: 0.4124 | MSE loss: 0.0072
# Epoch 35 | LPIPS loss: 0.4034 | MSE loss: 0.0072
# Epoch 36 | LPIPS loss: 0.3964 | MSE loss: 0.0071
# Epoch 37 | LPIPS loss: 0.3909 | MSE loss: 0.0070
# Epoch 38 | LPIPS loss: 0.3799 | MSE loss: 0.0069
# Epoch 39 | LPIPS loss: 0.3726 | MSE loss: 0.0068
# Epoch 40 | LPIPS loss: 0.3632 | MSE loss: 0.0067
# Epoch 41 | LPIPS loss: 0.3543 | MSE loss: 0.0067
# Epoch 42 | LPIPS loss: 0.3468 | MSE loss: 0.0066
# Epoch 43 | LPIPS loss: 0.3396 | MSE loss: 0.0065
# Epoch 44 | LPIPS loss: 0.3347 | MSE loss: 0.0065
# Epoch 45 | LPIPS loss: 0.3297 | MSE loss: 0.0064
# Epoch 46 | LPIPS loss: 0.3186 | MSE loss: 0.0063
# Epoch 47 | LPIPS loss: 0.3137 | MSE loss: 0.0063
# Epoch 48 | LPIPS loss: 0.3090 | MSE loss: 0.0063
# Epoch 49 | LPIPS loss: 0.3037 | MSE loss: 0.0062
# Epoch 50 | LPIPS loss: 0.2962 | MSE loss: 0.0061
# Epoch 51 | LPIPS loss: 0.2905 | MSE loss: 0.0061
# Epoch 52 | LPIPS loss: 0.2861 | MSE loss: 0.0061
# Epoch 53 | LPIPS loss: 0.2809 | MSE loss: 0.0059
# Epoch 54 | LPIPS loss: 0.2742 | MSE loss: 0.0058
# Epoch 55 | LPIPS loss: 0.2688 | MSE loss: 0.0058
# Epoch 56 | LPIPS loss: 0.2648 | MSE loss: 0.0058
# Epoch 57 | LPIPS loss: 0.2600 | MSE loss: 0.0057
# Epoch 58 | LPIPS loss: 0.2562 | MSE loss: 0.0056
# Epoch 59 | LPIPS loss: 0.2517 | MSE loss: 0.0055
# Epoch 60 | LPIPS loss: 0.2466 | MSE loss: 0.0054
# Epoch 61 | LPIPS loss: 0.2427 | MSE loss: 0.0053
# Epoch 62 | LPIPS loss: 0.2382 | MSE loss: 0.0052
# Epoch 63 | LPIPS loss: 0.2335 | MSE loss: 0.0051
# Epoch 64 | LPIPS loss: 0.2299 | MSE loss: 0.0050
# Epoch 65 | LPIPS loss: 0.2268 | MSE loss: 0.0049
# Epoch 66 | LPIPS loss: 0.2238 | MSE loss: 0.0048
# Epoch 67 | LPIPS loss: 0.2213 | MSE loss: 0.0047
# Epoch 68 | LPIPS loss: 0.2271 | MSE loss: 0.0046
# Epoch 69 | LPIPS loss: 0.2289 | MSE loss: 0.0045
# Epoch 70 | LPIPS loss: 0.2183 | MSE loss: 0.0044
# Epoch 71 | LPIPS loss: 0.2136 | MSE loss: 0.0042
# Epoch 72 | LPIPS loss: 0.2088 | MSE loss: 0.0041
# Epoch 73 | LPIPS loss: 0.2061 | MSE loss: 0.0040
# Epoch 74 | LPIPS loss: 0.2030 | MSE loss: 0.0039
# Epoch 75 | LPIPS loss: 0.2007 | MSE loss: 0.0038
# Epoch 76 | LPIPS loss: 0.1986 | MSE loss: 0.0036
# Epoch 77 | LPIPS loss: 0.1964 | MSE loss: 0.0035
# Epoch 78 | LPIPS loss: 0.1945 | MSE loss: 0.0034
# Epoch 79 | LPIPS loss: 0.1931 | MSE loss: 0.0033
# Epoch 80 | LPIPS loss: 0.1911 | MSE loss: 0.0031
# Epoch 81 | LPIPS loss: 0.1891 | MSE loss: 0.0030
# Epoch 82 | LPIPS loss: 0.1870 | MSE loss: 0.0029
# Epoch 83 | LPIPS loss: 0.1892 | MSE loss: 0.0029
# Epoch 84 | LPIPS loss: 0.1917 | MSE loss: 0.0027
# Epoch 85 | LPIPS loss: 0.1871 | MSE loss: 0.0027
# Epoch 86 | LPIPS loss: 0.1842 | MSE loss: 0.0026
# Epoch 87 | LPIPS loss: 0.1797 | MSE loss: 0.0025
# Epoch 88 | LPIPS loss: 0.1769 | MSE loss: 0.0024
# Epoch 89 | LPIPS loss: 0.1747 | MSE loss: 0.0024
# Epoch 90 | LPIPS loss: 0.1782 | MSE loss: 0.0023
# Epoch 91 | LPIPS loss: 0.1738 | MSE loss: 0.0023
# Epoch 92 | LPIPS loss: 0.1717 | MSE loss: 0.0022
# Epoch 93 | LPIPS loss: 0.1693 | MSE loss: 0.0021
# Epoch 94 | LPIPS loss: 0.1664 | MSE loss: 0.0022
# Epoch 95 | LPIPS loss: 0.1640 | MSE loss: 0.0021
# Epoch 96 | LPIPS loss: 0.1618 | MSE loss: 0.0020
# Epoch 97 | LPIPS loss: 0.1611 | MSE loss: 0.0020
# Epoch 98 | LPIPS loss: 0.1599 | MSE loss: 0.0020
# Epoch 99 | LPIPS loss: 0.1572 | MSE loss: 0.0020
# Epoch 100 | LPIPS loss: 0.1558 | MSE loss: 0.0020
#   class_name  lpips_model_lpips  mse_model_lpips  lpips_model_mse  \
# 0       frog           0.159052         0.311425         0.027395
# 1      horse           0.127803         0.287736         0.013877
# 2        cat           0.168822         0.331080         0.041385
# 3       ship           0.171335         0.285448         0.026150
#
#    mse_model_mse  lpips_model_psnr  mse_model_psnr
# 0       0.002257         16.020498       27.447744
# 1       0.002323         19.137568       27.038081
# 2       0.002780         14.141193       26.757060
# 3       0.001869         16.175920       27.816201

# %%
# Compare LPIPS score by class.
plot_df = class_df.melt(
    id_vars="class_name",
    value_vars=["lpips_model_lpips", "mse_model_lpips"],
    var_name="model",
    value_name="value",
)
plt.figure(figsize=(9, 4))
sns.barplot(data=plot_df, x="class_name", y="value", hue="model")
plt.title("Class-wise LPIPS comparison")
plt.show()

# Compare MSE score by class.
plot_df = class_df.melt(
    id_vars="class_name",
    value_vars=["lpips_model_mse", "mse_model_mse"],
    var_name="model",
    value_name="value",
)
plt.figure(figsize=(9, 4))
sns.barplot(data=plot_df, x="class_name", y="value", hue="model")
plt.title("Class-wise MSE comparison")
plt.show()

# %%
# Heatmap makes it easier to compare several metrics at once.
heatmap_df = class_df.set_index("class_name")[[
    "lpips_model_lpips",
    "mse_model_lpips",
    "lpips_model_mse",
    "mse_model_mse",
    "lpips_model_psnr",
    "mse_model_psnr",
]]
plt.figure(figsize=(10, 4))
sns.heatmap(heatmap_df, annot=True, fmt=".3f", cmap="viridis")
plt.title("Class-wise metric heatmap")
plt.show()

# %%
.0# Show one reconstruction grid for frog and one for horse.
for class_name in ["frog", "horse", "cat", "ship"]:
    model_lpips, model_mse, val_loader = reconstruction_cache[class_name]
    show_reconstructions(model_lpips, model_mse, val_loader, title=f"Reconstructions for class={class_name}")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
